# %%
pwd
# Out:
# 'C:\\Users\\ajayi'

# %%
cd ~
# Out:
# C:\Users\ajayi

# %%
cd Desktop
# Out:
# C:\Users\ajayi\Desktop

# %%
cd python_data_analysis
# Out:
# C:\Users\ajayi\Desktop\python_data_analysis

# %%
import pandas as pd        # data handling
import numpy as np         # numerical operations
import scipy.stats as stats # inferential statistics
import matplotlib.pyplot as plt  # plots

# %%
data = pd.read_excel("Mass_screening_agbado_april2026_analyze.xlsx")

# %%
data.head() 
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 62 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Gender                                          193 non-null    object
#  1   GenderLR                                        193 non-null    int64
#  2   Age                                             193 non-null    object
#  3   HLFE                                            193 non-null    object
#  4   Religion                                        193 non-null    object
#  5   Occupa                                          192 non-null    object
#  6   occupation                                      193 non-null    object
#  7   Marital_status                                  193 non-null    object
#  8   Family_type                                     175 non-null    object
#  9   Tribe                                           193 non-null    object
#  10  Prior_glucose_test                              193 non-null    object
#  11  Ever_told_to_have_Diabetes                      193 non-null    object
#  12  DM_duration                                     6 non-null      object
#  13  Medication                                      1 non-null      object
#  14  Prior_bp_check                                  193 non-null    object
#  15  Prior_told_of_htn                               193 non-null    object
#  16  Duration_of_htn                                 23 non-null     object
#  17  Drugs_for_htn                                   8 non-null      object
#  18  history_of_stroke_heart_disease_kidney_disease  193 non-null    object
#  19  long_term_medication                            193 non-null    object
#  20  Frequent_urination                              193 non-null    object
#  21  Excessive_thirst                                193 non-null    object
#  22  Unexplained_weight_loss                         193 non-null    object
#  23  Blurred_vision                                  193 non-null    object
#  24  Slow_healing_cuts_infections                    193 non-null    object
#  25  Numbness_tingling_hands_feets                   193 non-null    object
#  26  Frequent_headaches                              193 non-null    object
#  27  Dizziness                                       193 non-null    object
#  28  Shortness_of_breath                             193 non-null    object
#  29  legs_ankle_swelling                             193 non-null    object
#  30  Family_history_of_Diabetes                      193 non-null    object
#  31  Family_history_of_DMLR                          193 non-null    int64
#  32  Family_history_of_htn                           193 non-null    object
#  33  famly_hx_of_htnLR                               193 non-null    int64
#  34  smoke_tobacco                                   193 non-null    object
#  35  tobaccoLR                                       193 non-null    int64
#  36  Alcohol_frequency_per_week                      193 non-null    object
#  37  alcohol                                         193 non-null    object
#  38  alcoholLR                                       193 non-null    int64
#  39  Physical_activity                               193 non-null    object
#  40  Typical_daily_fruits_vegetables_portion         193 non-null    object
#  41  add_salts_to_cooked_food                        193 non-null    object
#  42  dietary_saltLR                                  193 non-null    int64
#  43  high_blood_sugar_during_pregnancy               139 non-null    object
#  44  BMI                                             193 non-null    float64
#  45  BMI_cat                                         193 non-null    object
#  46  bmi_2l                                          193 non-null    object
#  47  SBP                                             193 non-null    int64
#  48  SBP_2_level_cat                                 193 non-null    object
#  49  SBP_2lLR                                        193 non-null    int64
#  50  SBP_cat                                         193 non-null    object
#  51  htn_2l                                          193 non-null    object
#  52  htn_2llr                                        193 non-null    int64
#  53  DBP                                             193 non-null    int64
#  54  DBP_2_level_cat                                 193 non-null    object
#  55  DBP_2lLR                                        193 non-null    int64
#  56  DBP_cat                                         193 non-null    object
#  57  RBG                                             193 non-null    float64
#  58  RBG_cat                                         193 non-null    object
#  59  rbg_2l                                          193 non-null    object
#  60  rbg_2llr                                        193 non-null    int64
#  61  RBG_LR                                          193 non-null    int64
# dtypes: float64(2), int64(13), object(47)
# memory usage: 93.6+ KB
#          GenderLR  Family_history_of_DMLR  famly_hx_of_htnLR   tobaccoLR  \
# count  193.000000              193.000000         193.000000  193.000000
# mean     0.269430                0.077720           0.056995    0.082902
# std      0.444818                0.268427           0.232436    0.276450
# min      0.000000                0.000000           0.000000    0.000000
# 25%      0.000000                0.000000           0.000000    0.000000
# 50%      0.000000                0.000000           0.000000    0.000000
# 75%      1.000000                0.000000           0.000000    0.000000
# max      1.000000                1.000000           1.000000    1.000000
#
#         alcoholLR  dietary_saltLR         BMI         SBP    SBP_2lLR  \
# count  193.000000      193.000000  193.000000  193.000000  193.000000
# mean     0.222798        0.305699   24.825420  129.445596    0.284974
# std      0.417206        0.461901    5.076709   23.151638    0.452576
# min      0.000000        0.000000   13.872374   92.000000    0.000000
# 25%      0.000000        0.000000   21.220384  112.000000    0.000000
# 50%      0.000000        0.000000   23.828125  126.000000    0.000000
# 75%      0.000000        1.000000   26.854406  142.000000    1.000000
# max      1.000000        1.000000   45.981356  207.000000    1.000000
#
#          htn_2llr         DBP    DBP_2lLR         RBG    rbg_2llr      RBG_LR
# count  193.000000  193.000000  193.000000  193.000000  193.000000  193.000000
# mean     0.316062   80.150259    0.222798    7.780656    0.067358    0.362694
# std      0.466147   12.586915    0.417206    3.088208    0.251292    0.482028
# min      0.000000   58.000000    0.000000    3.722222    0.000000    0.000000
# 25%      0.000000   71.000000    0.000000    6.166667    0.000000    0.000000
# 50%      0.000000   78.000000    0.000000    7.055556    0.000000    0.000000
# 75%      1.000000   86.000000    0.000000    8.388889    0.000000    1.000000
# max      1.000000  120.000000    1.000000   28.833333    1.000000    1.000000

# %%
# 1. Automatically grab all categorical columns
cat_cols = data.select_dtypes(include=['object', 'category']).columns
# 2. Loop through them and print counts and percentages
for col in cat_cols:
    print(f"--- {col} ---")
    
    # Calculate counts
    counts = data[col].value_counts()
    
    # Calculate percentages (normalize=True)
    percents = data[col].value_counts(normalize=True) * 100
    
    # Combine them into a small table for readability
    df_summary = pd.DataFrame({'Count': counts, 'Percentage (%)': percents})
    print(df_summary)
    print("\n") # Adds a space between columns
# Out:
# --- Gender ---
#         Count  Percentage (%)
# Gender
# Female    141       73.056995
# Male       52       26.943005
#
#
# --- Age ---
#               Count  Percentage (%)
# Age
# 60 and above     69       35.751295
# 50-59            42       21.761658
# 40-49            42       21.761658
# 18-29            21       10.880829
# 30-39            19        9.844560
#
#
# --- HLFE ---
#                  Count  Percentage (%)
# HLFE
# None or primary     87       45.077720
# Secondary           77       39.896373
# Tertiary            29       15.025907
#
#
# --- Religion ---
#                 Count  Percentage (%)
# Religion
# Christianity      174       90.155440
# Islam              17        8.808290
# Traditionalist      2        1.036269
#
#
# --- Occupa ---
#                             Count  Percentage (%)
# Occupa
# Trader                         40       20.833333
# Trader                         23       11.979167
# Farmer                         14        7.291667
# Farmer                         13        6.770833
# Trading                        11        5.729167
# Business                        6        3.125000
# Trading                         6        3.125000
# Tailor                          5        2.604167
# Civil servant                   5        2.604167
# Student                         4        2.083333
# Tailor                          4        2.083333
# Retiree                         3        1.562500
# Fashion designer                3        1.562500
# Driver                          3        1.562500
# Civil Servant                   3        1.562500
# Retiree                         2        1.041667
# Corper                          2        1.041667
# Hair dresser                    2        1.041667
# Food vendor                     2        1.041667
# Farming                         2        1.041667
# Food seller                     1        0.520833
# Civil servant.                  1        0.520833
# Student                         1        0.520833
# Teacher                         1        0.520833
# Farmer.                         1        0.520833
# Catering                        1        0.520833
# Artisan                         1        0.520833
# Traders                         1        0.520833
# Artisan                         1        0.520833
# Teaching                        1        0.520833
# Self-employed                   1        0.520833
# Food vendor                     1        0.520833
# Retired                         1        0.520833
# Driver                          1        0.520833
# Hustler                         1        0.520833
# Hairdresser                     1        0.520833
# Auxillary Nirse                 1        0.520833
# Seller                          1        0.520833
# Fashion Designing               1        0.520833
# Saleswoman                      1        0.520833
# Civil service                   1        0.520833
# Farmer, Vulcanizer              1        0.520833
# Mechanic                        1        0.520833
# Clergy                          1        0.520833
# Menial job                      1        0.520833
# Clergywoman                     1        0.520833
# Foodseller                      1        0.520833
# Tailoring (Apprenticeship)      1        0.520833
# Chemist                         1        0.520833
# Hair dresser                    1        0.520833
# Hair dressing                   1        0.520833
# Fashion Designer                1        0.520833
# Farmer/ Food Seller             1        0.520833
# Retired civil servant           1        0.520833
# Civil Servant                   1        0.520833
# Farming                         1        0.520833
# Security                        1        0.520833
# Rt. Civil Servant               1        0.520833
# Corper                          1        0.520833
#
#
# --- occupation ---
#                      Count  Percentage (%)
# occupation
# non_farm_occupation    158       81.865285
# farm_occupation         33       17.098446
# unemployed               2        1.036269
#
#
# --- Marital_status ---
#                 Count  Percentage (%)
# Marital_status
# Married           128       66.321244
# Widow/Widower      34       17.616580
# Single             18        9.326425
# Separated          12        6.217617
# Divorced            1        0.518135
#
#
# --- Family_type ---
#              Count  Percentage (%)
# Family_type
# Monogamous     107       61.142857
# Polygamous      68       38.857143
#
#
# --- Tribe ---
#         Count  Percentage (%)
# Tribe
# Yoruba    177       91.709845
# Others     10        5.181347
# Igbo        6        3.108808
#
#
# --- Prior_glucose_test ---
#                     Count  Percentage (%)
# Prior_glucose_test
# No                    107       55.440415
# Yes                    86       44.559585
#
#
# --- Ever_told_to_have_Diabetes ---
#                             Count  Percentage (%)
# Ever_told_to_have_Diabetes
# No                            185       95.854922
# Yes                             8        4.145078
#
#
# --- DM_duration ---
#              Count  Percentage (%)
# DM_duration
# <1               3       50.000000
# 10               1       16.666667
# 4                1       16.666667
# 1                1       16.666667
#
#
# --- Medication ---
#                      Count  Percentage (%)
# Medication
# metformin glipizide      1           100.0
#
#
# --- Prior_bp_check ---
#                 Count  Percentage (%)
# Prior_bp_check
# Yes               156       80.829016
# No                 37       19.170984
#
#
# --- Prior_told_of_htn ---
#                    Count  Percentage (%)
# Prior_told_of_htn
# No                   154       79.792746
# Yes                   39       20.207254
#
#
# --- Duration_of_htn ---
#                  Count  Percentage (%)
# Duration_of_htn
# <1                  11       47.826087
# 2                    3       13.043478
# 3                    2        8.695652
# 1                    2        8.695652
# 10                   2        8.695652
# 7                    1        4.347826
# 5                    1        4.347826
# 21                   1        4.347826
#
#
# --- Drugs_for_htn ---
#                Count  Percentage (%)
# Drugs_for_htn
# nife               5            62.5
# amlo               2            25.0
# lisin              1            12.5
#
#
# --- history_of_stroke_heart_disease_kidney_disease ---
#                                                 Count  Percentage (%)
# history_of_stroke_heart_disease_kidney_disease
# No                                                190       98.445596
# Yes                                                 3        1.554404
#
#
# --- long_term_medication ---
#                       Count  Percentage (%)
# long_term_medication
# No                      164       84.974093
# Yes                      29       15.025907
#
#
# --- Frequent_urination ---
#                     Count  Percentage (%)
# Frequent_urination
# No                    158       81.865285
# Yes                    35       18.134715
#
#
# --- Excessive_thirst ---
#                   Count  Percentage (%)
# Excessive_thirst
# No                  177       91.709845
# Yes                  16        8.290155
#
#
# --- Unexplained_weight_loss ---
#                          Count  Percentage (%)
# Unexplained_weight_loss
# No                         164       84.974093
# Yes                         29       15.025907
#
#
# --- Blurred_vision ---
#                 Count  Percentage (%)
# Blurred_vision
# No                130       67.357513
# Yes                63       32.642487
#
#
# --- Slow_healing_cuts_infections ---
#                               Count  Percentage (%)
# Slow_healing_cuts_infections
# No                              183       94.818653
# Yes                              10        5.181347
#
#
# --- Numbness_tingling_hands_feets ---
#                                Count  Percentage (%)
# Numbness_tingling_hands_feets
# No                               109       56.476684
# Yes                               84       43.523316
#
#
# --- Frequent_headaches ---
#                     Count  Percentage (%)
# Frequent_headaches
# No                    142        73.57513
# Yes                    51        26.42487
#
#
# --- Dizziness ---
#            Count  Percentage (%)
# Dizziness
# No           146       75.647668
# Yes           47       24.352332
#
#
# --- Shortness_of_breath ---
#                      Count  Percentage (%)
# Shortness_of_breath
# No                     172       89.119171
# Yes                     21       10.880829
#
#
# --- legs_ankle_swelling ---
#                      Count  Percentage (%)
# legs_ankle_swelling
# No                     181       93.782383
# Yes                     12        6.217617
#
#
# --- Family_history_of_Diabetes ---
#                             Count  Percentage (%)
# Family_history_of_Diabetes
# No                            142       73.575130
# Don't know                     36       18.652850
# Yes                            15        7.772021
#
#
# --- Family_history_of_htn ---
#                        Count  Percentage (%)
# Family_history_of_htn
# No                       141       73.056995
# Don't know                41       21.243523
# Yes                       11        5.699482
#
#
# --- smoke_tobacco ---
#                Count  Percentage (%)
# smoke_tobacco
# Never            177       91.709845
# Currently         10        5.181347
# In the past        6        3.108808
#
#
# --- Alcohol_frequency_per_week ---
#                             Count  Percentage (%)
# Alcohol_frequency_per_week
# 0                             150       77.720207
# 45659                          25       12.953368
# 45723                           9        4.663212
# >7                              9        4.663212
#
#
# --- alcohol ---
#          Count  Percentage (%)
# alcohol
# No         150       77.720207
# Yes         43       22.279793
#
#
# --- Physical_activity ---
#                    Count  Percentage (%)
# Physical_activity
# Moderate             120       62.176166
# Light                 43       22.279793
# Heavy                 27       13.989637
# Sedentary              3        1.554404
#
#
# --- Typical_daily_fruits_vegetables_portion ---
#                                          Count  Percentage (%)
# Typical_daily_fruits_vegetables_portion
# 1                                           98       50.777202
# 0                                           43       22.279793
# 2                                           36       18.652850
# 3+                                          16        8.290155
#
#
# --- add_salts_to_cooked_food ---
#                           Count  Percentage (%)
# add_salts_to_cooked_food
# No                          134       69.430052
# Yes                          59       30.569948
#
#
# --- high_blood_sugar_during_pregnancy ---
#                                    Count  Percentage (%)
# high_blood_sugar_during_pregnancy
# No                                   139           100.0
#
#
# --- BMI_cat ---
#                                                  Count  Percentage (%)
# BMI_cat
# "<=18.5 - 24.9" "Normal weight and underweight"    114       59.067358
# "25 - 29.9" "Overweight"                            49       25.388601
# ">=30" "Obesity"                                    30       15.544041
#
#
# --- bmi_2l ---
#                Count  Percentage (%)
# bmi_2l
# norm or und      114       59.067358
# over or obese     79       40.932642
#
#
# --- SBP_2_level_cat ---
#                  Count  Percentage (%)
# SBP_2_level_cat
# Nohypertension     138       71.502591
# Hypertension        55       28.497409
#
#
# --- SBP_cat ---
#                                Count  Percentage (%)
# SBP_cat
# "<120mmHg Normal"                 79       40.932642
# "120-139mmHg Prehypertension"     59       30.569948
# ">=140mmHg Hypertension"          55       28.497409
#
#
# --- htn_2l ---
#         Count  Percentage (%)
# htn_2l
# Normal    132       68.393782
# HTN        61       31.606218
#
#
# --- DBP_2_level_cat ---
#                  Count  Percentage (%)
# DBP_2_level_cat
# Nohypertension     150       77.720207
# Hypertension        43       22.279793
#
#
# --- DBP_cat ---
#                              Count  Percentage (%)
# DBP_cat
# "<80mmHg Normal"               111       57.512953
# ">= 90mmHg Hypertension"        42       21.761658
# "80-89mmHg Prehypertension"     40       20.725389
#
#
# --- RBG_cat ---
#                          Count  Percentage (%)
# RBG_cat
# "<7.8mmol/l Normal"        123       63.730570
# "7.8-11.0mmol/l IGT"        57       29.533679
# ">=11.1mmol/l Diabetes"     13        6.735751
#
#
# --- rbg_2l ---
#           Count  Percentage (%)
# rbg_2l
# normal      180       93.264249
# diabetes     13        6.735751

# %%
from scipy.stats import chi2_contingency
import pandas as pd

# 1. Define your target variable and a list of factors you want to test
target = 'rbg_2l'
factors = ['BMI_cat', 'Gender','HLFE', 'occupation', 'Family_type', 'Age', 'Physical_activity', 'Typical_daily_fruits_vegetables_portion',  'add_salts_to_cooked_food', 'alcohol', 'bmi_2l', 'htn_2llr', 'smoke_tobacco'] # Add all your column names here

# 2. Loop through each factor
for factor in factors:
    print(f"\n" + "="*30)
    print(f"ANALYSIS: {factor} vs {target}")
    print("="*30)
    
    # Create the frequency table (Counts)
    ct_counts = pd.crosstab(data[factor], data[target])
    
    # Create the percentage table (Row-wise percentages)
    ct_percent = pd.crosstab(data[factor], data[target], normalize='index') * 100
    
    # Perform the Chi-Square Test
    chi2, p, dof, expected = chi2_contingency(ct_counts)
    
    # Display Results
    print("\n--- Frequency Count Table (Counts) ---")
    print(ct_counts)
    print("--- Percentage Table (Row %) ---")
    print(ct_percent.round(2))
    
    print("\n--- Chi-Square Test Results ---")
    print(f"Chi-Square Statistic: {chi2:.4f}")
    print(f"P-value: {p:.4f}")
    print(f"Degrees of Freedom: {dof}")
    
    # Quick Interpretation
    alpha = 0.05
    if p < alpha:
        print("\nResult: Statistically significant (Reject H0)")
    else:
        print("\nResult: Not statistically significant (Fail to reject H0)")
# Out:
# ==============================
# ANALYSIS: BMI_cat vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l                                           diabetes  normal
# BMI_cat
# "25 - 29.9" "Overweight"                                4      45
# "<=18.5 - 24.9" "Normal weight and underweight"         4     110
# ">=30" "Obesity"                                        5      25
# --- Percentage Table (Row %) ---
# rbg_2l                                           diabetes  normal
# BMI_cat
# "25 - 29.9" "Overweight"                             8.16   91.84
# "<=18.5 - 24.9" "Normal weight and underweight"      3.51   96.49
# ">=30" "Obesity"                                    16.67   83.33
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 6.7584
# P-value: 0.0341
# Degrees of Freedom: 2
#
# Result: Statistically significant (Reject H0)
#
# ==============================
# ANALYSIS: Gender vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l  diabetes  normal
# Gender
# Female        10     131
# Male           3      49
# --- Percentage Table (Row %) ---
# rbg_2l  diabetes  normal
# Gender
# Female      7.09   92.91
# Male        5.77   94.23
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.0000
# P-value: 0.9987
# Degrees of Freedom: 1
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: HLFE vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l           diabetes  normal
# HLFE
# None or primary         8      79
# Secondary               4      73
# Tertiary                1      28
# --- Percentage Table (Row %) ---
# rbg_2l           diabetes  normal
# HLFE
# None or primary      9.20   90.80
# Secondary            5.19   94.81
# Tertiary             3.45   96.55
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 1.6278
# P-value: 0.4431
# Degrees of Freedom: 2
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: occupation vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l               diabetes  normal
# occupation
# farm_occupation             2      31
# non_farm_occupation        11     147
# unemployed                  0       2
# --- Percentage Table (Row %) ---
# rbg_2l               diabetes  normal
# occupation
# farm_occupation          6.06   93.94
# non_farm_occupation      6.96   93.04
# unemployed               0.00  100.00
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.1813
# P-value: 0.9134
# Degrees of Freedom: 2
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: Family_type vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l       diabetes  normal
# Family_type
# Monogamous          9      98
# Polygamous          3      65
# --- Percentage Table (Row %) ---
# rbg_2l       diabetes  normal
# Family_type
# Monogamous       8.41   91.59
# Polygamous       4.41   95.59
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.5092
# P-value: 0.4755
# Degrees of Freedom: 1
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: Age vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l        diabetes  normal
# Age
# 18-29                0      21
# 30-39                2      17
# 40-49                4      38
# 50-59                3      39
# 60 and above         4      65
# --- Percentage Table (Row %) ---
# rbg_2l        diabetes  normal
# Age
# 18-29             0.00  100.00
# 30-39            10.53   89.47
# 40-49             9.52   90.48
# 50-59             7.14   92.86
# 60 and above      5.80   94.20
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 2.5788
# P-value: 0.6306
# Degrees of Freedom: 4
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: Physical_activity vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l             diabetes  normal
# Physical_activity
# Heavy                     3      24
# Light                     1      42
# Moderate                  9     111
# Sedentary                 0       3
# --- Percentage Table (Row %) ---
# rbg_2l             diabetes  normal
# Physical_activity
# Heavy                 11.11   88.89
# Light                  2.33   97.67
# Moderate               7.50   92.50
# Sedentary              0.00  100.00
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 2.4823
# P-value: 0.4785
# Degrees of Freedom: 3
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: Typical_daily_fruits_vegetables_portion vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l                                   diabetes  normal
# Typical_daily_fruits_vegetables_portion
# 0                                               1      42
# 1                                               6      92
# 2                                               4      32
# 3+                                              2      14
# --- Percentage Table (Row %) ---
# rbg_2l                                   diabetes  normal
# Typical_daily_fruits_vegetables_portion
# 0                                            2.33   97.67
# 1                                            6.12   93.88
# 2                                           11.11   88.89
# 3+                                          12.50   87.50
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 3.3333
# P-value: 0.3430
# Degrees of Freedom: 3
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: add_salts_to_cooked_food vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l                    diabetes  normal
# add_salts_to_cooked_food
# No                              10     124
# Yes                              3      56
# --- Percentage Table (Row %) ---
# rbg_2l                    diabetes  normal
# add_salts_to_cooked_food
# No                            7.46   92.54
# Yes                           5.08   94.92
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.0873
# P-value: 0.7676
# Degrees of Freedom: 1
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: alcohol vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l   diabetes  normal
# alcohol
# No             10     140
# Yes             3      40
# --- Percentage Table (Row %) ---
# rbg_2l   diabetes  normal
# alcohol
# No           6.67   93.33
# Yes          6.98   93.02
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.0000
# P-value: 1.0000
# Degrees of Freedom: 1
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: bmi_2l vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l         diabetes  normal
# bmi_2l
# norm or und           4     110
# over or obese         9      70
# --- Percentage Table (Row %) ---
# rbg_2l         diabetes  normal
# bmi_2l
# norm or und        3.51   96.49
# over or obese     11.39   88.61
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 3.4470
# P-value: 0.0634
# Degrees of Freedom: 1
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: htn_2llr vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l    diabetes  normal
# htn_2llr
# 0                9     123
# 1                4      57
# --- Percentage Table (Row %) ---
# rbg_2l    diabetes  normal
# htn_2llr
# 0             6.82   93.18
# 1             6.56   93.44
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.0000
# P-value: 1.0000
# Degrees of Freedom: 1
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: smoke_tobacco vs rbg_2l
# ==============================
#
# --- Frequency Count Table (Counts) ---
# rbg_2l         diabetes  normal
# smoke_tobacco
# Currently             1       9
# In the past           0       6
# Never                12     165
# --- Percentage Table (Row %) ---
# rbg_2l         diabetes  normal
# smoke_tobacco
# Currently         10.00   90.00
# In the past        0.00  100.00
# Never              6.78   93.22
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.6035
# P-value: 0.7395
# Degrees of Freedom: 2
#
# Result: Not statistically significant (Fail to reject H0)

# %%
# for logistic regression for a categorical age column

import pandas as pd
import statsmodels.api as sm
import numpy as np

# 1. LOAD DATA
# Make sure the file name matches your edited Excel file
df = pd.read_excel("Mass_screening_agbado_april2026_analyze.xlsx")

# 2. PRE-PROCESSING
# Merge younger groups to ensure we have 'events' in the reference category
df['Age_Fixed'] = df['Age'].replace({'18-29': '18-39', '30-39': '18-39'})

# Ensure target is float (1 = High SBP, 0 = Normal)
y = df['rbg_2llr'].astype(float)

# Define all independent variables for the Adjusted model
covariates = [
    'BMI', 'GenderLR', 'SBP', 'DBP', 'Family_history_of_DMLR', 
     'tobaccoLR', 'alcoholLR', 'Age_Fixed'
]

# 3. ANALYSIS FUNCTION
def run_logit(cols):
    # drop_first=True makes the first alphabetical category the reference group
    X = pd.get_dummies(df[cols], drop_first=True, dtype=int)
    X = sm.add_constant(X)
    return sm.Logit(y, X).fit(method='bfgs', disp=False)

# 4. BUILD RESULTS TABLE
final_results = []

# Get Adjusted stats (all variables)
adj_model = run_logit(covariates)
a_ors, a_cis, a_ps = np.exp(adj_model.params), np.exp(adj_model.conf_int()), adj_model.pvalues

# Get Crude stats (one variable at a time)
for var in covariates:
    c_model = run_logit([var])
    c_ors, c_cis, c_ps = np.exp(c_model.params), np.exp(c_model.conf_int()), c_model.pvalues
    
    for i in range(1, len(c_ors)): # Skip constant
        v_name = c_ors.index[i]
        
        final_results.append({
            'Variable': v_name,
            'Crude OR (95% CI)': f"{c_ors[i]:.2f} ({c_cis.iloc[i,0]:.2f}-{c_cis.iloc[i,1]:.2f})",
            'p-value (Crude)': f"{c_ps[i]:.3f}",
            'Adjusted OR (95% CI)': f"{a_ors[v_name]:.2f} ({a_cis.loc[v_name,0]:.2f}-{a_cis.loc[v_name,1]:.2f})",
            'p-value (Adjusted)': f"{a_ps[v_name]:.3f}"
        })

# 5. DISPLAY
output_table = pd.DataFrame(final_results)
print("\n--- FINAL PUBLICATION TABLE ---")
print(output_table.to_string(index=False))

# Optional: Save to Excel for easy copy-pasting into Word
# output_table.to_excel('Regression_Results.xlsx', index=False)
# Out:
# C:\Users\ajayi\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Crude OR (95% CI)': f"{c_ors[i]:.2f} ({c_cis.iloc[i,0]:.2f}-{c_cis.iloc[i,1]:.2f})",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'p-value (Crude)': f"{c_ps[i]:.3f}",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Crude OR (95% CI)': f"{c_ors[i]:.2f} ({c_cis.iloc[i,0]:.2f}-{c_cis.iloc[i,1]:.2f})",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'p-value (Crude)': f"{c_ps[i]:.3f}",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Crude OR (95% CI)': f"{c_ors[i]:.2f} ({c_cis.iloc[i,0]:.2f}-{c_cis.iloc[i,1]:.2f})",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'p-value (Crude)': f"{c_ps[i]:.3f}",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Crude OR (95% CI)': f"{c_ors[i]:.2f} ({c_cis.iloc[i,0]:.2f}-{c_cis.iloc[i,1]:.2f})",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'p-value (Crude)': f"{c_ps[i]:.3f}",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Crude OR (95% CI)': f"{c_ors[i]:.2f} ({c_cis.iloc[i,0]:.2f}-{c_cis.iloc[i,1]:.2f})",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'p-value (Crude)': f"{c_ps[i]:.3f}",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Crude OR (95% CI)': f"{c_ors[i]:.2f} ({c_cis.iloc[i,0]:.2f}-{c_cis.iloc[i,1]:.2f})",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'p-value (Crude)': f"{c_ps[i]:.3f}",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Crude OR (95% CI)': f"{c_ors[i]:.2f} ({c_cis.iloc[i,0]:.2f}-{c_cis.iloc[i,1]:.2f})",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'p-value (Crude)': f"{c_ps[i]:.3f}",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Crude OR (95% CI)': f"{c_ors[i]:.2f} ({c_cis.iloc[i,0]:.2f}-{c_cis.iloc[i,1]:.2f})",
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_20880\3463126940.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'p-value (Crude)': f"{c_ps[i]:.3f}",
# --- FINAL PUBLICATION TABLE ---
#               Variable Crude OR (95% CI) p-value (Crude) Adjusted OR (95% CI) p-value (Adjusted)
#                    BMI  1.10 (1.01-1.21)           0.037     1.09 (0.97-1.22)              0.134
#               GenderLR  0.80 (0.21-3.04)           0.745     1.44 (0.21-9.66)              0.710
#                    SBP  1.00 (0.98-1.03)           0.773     0.99 (0.94-1.04)              0.628
#                    DBP  1.02 (0.98-1.06)           0.351     1.01 (0.92-1.10)              0.856
# Family_history_of_DMLR 6.83 (1.81-25.72)           0.005    8.14 (1.82-36.47)              0.006
#              tobaccoLR  0.92 (0.11-7.54)           0.936    2.34 (0.23-23.77)              0.471
#              alcoholLR  1.05 (0.28-4.00)           0.943     0.58 (0.10-3.39)              0.548
#        Age_Fixed_40-49 2.00 (0.35-11.58)           0.439    2.42 (0.34-17.22)              0.378
#        Age_Fixed_50-59  1.46 (0.23-9.24)           0.687    2.37 (0.29-19.38)              0.420
# Age_Fixed_60 and above  1.17 (0.20-6.69)           0.861    2.80 (0.35-22.34)              0.332
