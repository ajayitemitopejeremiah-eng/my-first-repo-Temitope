# %%
import py

# %%
import pandas as pd        # data handling
import numpy as np         # numerical operations
import scipy.stats as stats # inferential statistics
import matplotlib.pyplot as plt  # plots

# %%
pwd
# Out:
# 'C:\\Users\\ajayi\\Desktop\\python_data_analysis'

# %%
cd Desktop
# Out:
# C:\Users\ajayi\Desktop

# %%
pwd
# Out:
# 'C:\\Users\\ajayi\\Desktop'

# %%
cd python_data_analysis
# Out:
# C:\Users\ajayi\Desktop\python_data_analysis

# %%
data = pd.read_excel("dataset_cord_care_analyze.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 97 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   health_facility                             350 non-null    object
#  1   sex                                         351 non-null    object
#  2   age_of_child_cat                            352 non-null    object
#  3   child_weight_today                          351 non-null    float64
#  4   parents_religion                            352 non-null    object
#  5   ethnicity                                   352 non-null    object
#  6   residence                                   351 non-null    object
#  7   residenceL                                  351 non-null    object
#  8   residenceLR                                 351 non-null    float64
#  9   mother_hlfe                                 352 non-null    object
#  10  mother_hlfe_2cat                            352 non-null    object
#  11  mother_hlfeLR                               352 non-null    int64
#  12  father_hlfe                                 352 non-null    object
#  13  mother_occupation                           350 non-null    object
#  14  mother_occupationL                          350 non-null    object
#  15  mother_occupationLR                         349 non-null    float64
#  16  father_occupation                           351 non-null    object
#  17  mother_age                                  352 non-null    int64
#  18  mother_age_cat                              352 non-null    object
#  19  parity                                      352 non-null    int64
#  20  parity_cat                                  352 non-null    object
#  21  parity_2ca2t                                352 non-null    object
#  22  parity_catLR                                352 non-null    int64
#  23  mother_marital_status                       352 non-null    object
#  24  attended_anc_in_preg                        352 non-null    object
#  25  visit_no                                    352 non-null    int64
#  26  visit_no_cat                                352 non-null    object
#  27  adequate_anc                                352 non-null    object
#  28  adequate_ancLR                              352 non-null    int64
#  29  place_of_anc                                346 non-null    object
#  30  place_of_anc_2_cat                          346 non-null    object
#  31  place_of_ancLR                              346 non-null    float64
#  32  had_health_talk_on_ucc                      334 non-null    object
#  33  place_of_birth_of_index_child               338 non-null    object
#  34  place_of_birth_2cat                         338 non-null    object
#  35  place_of_birthLR                            338 non-null    float64
#  36  child_bw                                    297 non-null    float64
#  37  child_bw_cat                                297 non-null    object
#  38  object_used_to_cut_cord                     349 non-null    object
#  39  what_was_applied_to_the_cord_after_cut      341 non-null    object
#  40  thread_soaked_in_metspirit                  77 non-null     object
#  41  age_at_cord_dropped                         331 non-null    object
#  42  aware_of_ucc                                350 non-null    object
#  43  wash_hands_before_cord_care                 350 non-null    object
#  44  agent_used_to_clean_cord_before_drop        350 non-null    object
#  45  Hot_water_compress                          350 non-null    float64
#  46  cotton_wool                                 350 non-null    float64
#  47  methylated_spirit_only                      350 non-null    float64
#  48  chlorhexidine_gel_only                      350 non-null    float64
#  49  use_CLGcorrect_LR                           350 non-null    float64
#  50  use_CLGcorrect                              349 non-null    object
#  51  toooth_paste                                350 non-null    float64
#  52  shea_butter                                 350 non-null    float64
#  53  metholatum                                  350 non-null    float64
#  54  herbs/local_concortion                      350 non-null    float64
#  55  practice_outcome                            345 non-null    object
#  56  practice_outcomeLR                          345 non-null    float64
#  57  multi_agent                                 344 non-null    object
#  58  freq_of_metspirit_use_in_a_day_cat          282 non-null    object
#  59  freq_of_chlorhexidine_use_in_a_day_cat      99 non-null     object
#  60  taught_on_chlorhexidine_app                 151 non-null    object
#  61  sure_using_chlorhexidine_correctly          115 non-null    object
#  62  good_to_expose_cord_to_fresh_air            347 non-null    object
#  63  good_to_expose_cord_to_keep_cord_in_diaper  347 non-null    object
#  64  agent_applied_after_cord_drop               18 non-null     object
#  65  safe_postsep_care                           335 non-null    object
#  66  safe_postsep_careLR                         335 non-null    float64
#  67  multiple_agent_applied_after_cord_drop      326 non-null    object
#  68  Chlorhexidine gel                           40 non-null     object
#  69  3                                           171 non-null    object
#  70  4                                           49 non-null     object
#  71  5                                           53 non-null     object
#  72  6                                           48 non-null     object
#  73  7                                           7 non-null      object
#  74  duration_of_cord_care_practice_cat          206 non-null    object
#  75  tiime_intended_to_stop_cat                  243 non-null    object
#  76  Post_sep_counsel                            313 non-null    object
#  77  Post_sep_counselLR                          313 non-null    float64
#  78  who_told_you                                26 non-null     object
#  79  Previous_exp_source                         343 non-null    float64
#  80  sister_source                               343 non-null    float64
#  81  multiple_source                             343 non-null    object
#  82  Grandmother_source                          343 non-null    float64
#  83  Other_Mothers_source                        343 non-null    float64
#  84  Friends_source                              343 non-null    float64
#  85  Healthcareworkers_source                    343 non-null    float64
#  86  Healthcareworkers_source2cat                343 non-null    object
#  87  Healthcareworkers_sourceLR                  343 non-null    float64
#  88  Internet_source                             343 non-null    float64
#  89  who_decides_how_to_care_for_the_child_cc    203 non-null    object
#  90  self_decision_2cat                          322 non-null    object
#  91  self_decisionLR                             322 non-null    float64
#  92  multiple                                    322 non-null    object
#  93  2                                           72 non-null     object
#  94  3.1                                         52 non-null     object
#  95  4.1                                         2 non-null      object
#  96  5.1                                         1 non-null      object
# dtypes: float64(27), int64(6), object(64)
# memory usage: 266.9+ KB

# %%
import openpyxl

# 1. Check the true physical dimensions of the Excel sheet from the file system
wb = openpyxl.load_workbook("dataset_cord_care_analyze.xlsx", read_only=True)
sheet = wb.active
print(f"--- Excel File Properties ---")
print(f"Total physical rows in Excel sheet: {sheet.max_row}")
print(f"Total physical columns in Excel sheet: {sheet.max_column}\n")

# 2. Check if pandas is dropping rows during import due to blank lines at the bottom
print(f"--- Pandas DataFrame Shape ---")
print(f"Rows loaded by pandas: {data.shape[0]} (excluding header row)")
print(f"Columns loaded by pandas: {data.shape[1]}\n")

# 3. Look for hidden NaN or completely empty rows in your dataframe
empty_rows = data.isnull().all(axis=1).sum()
print(f"--- Blank Row Check ---")
print(f"Number of completely blank rows found and skipped: {empty_rows}")

# 4. Check the true range of your dataframe index values
print(f"\nDataFrame Index Range: Minimum index = {data.index.min()}, Maximum index = {data.index.max()}")
# Out:
# --- Excel File Properties ---
# Total physical rows in Excel sheet: 353
# Total physical columns in Excel sheet: 97
#
# --- Pandas DataFrame Shape ---
# Rows loaded by pandas: 350 (excluding header row)
# Columns loaded by pandas: 97
#
# --- Blank Row Check ---
# Number of completely blank rows found and skipped: 0
#
# DataFrame Index Range: Minimum index = 1, Maximum index = 351

# %%
# Load the raw file with no type conversions to prevent skipping rows
raw_test = pd.read_excel("dataset_cord_care_analyze.xlsx", keep_default_na=False)

print(f"Forced load shape: {raw_test.shape}")
print(f"Difference: {raw_test.shape[0] - data.shape[0]} row(s)")

# Display the absolute last 5 rows of the Excel sheet to find the anomalies
raw_test.tail(5)
# Out:
# Forced load shape: (352, 97)
# Difference: 2 row(s)
#     health_facility sex age_of_child_cat child_weight_today parents_religion ethnicity residence residenceL residenceLR mother_hlfe  mother_hlfe_2cat  mother_hlfeLR father_hlfe     mother_occupation             mother_occupationL mother_occupationLR father_occupation  mother_age mother_age_cat  parity parity_cat parity_2ca2t  parity_catLR mother_marital_status attended_anc_in_preg  visit_no visit_no_cat adequate_anc  adequate_ancLR      place_of_anc   place_of_anc_2_cat place_of_ancLR had_health_talk_on_ucc place_of_birth_of_index_child  place_of_birth_2cat place_of_birthLR child_bw child_bw_cat object_used_to_cut_cord what_was_applied_to_the_cord_after_cut thread_soaked_in_metspirit age_at_cord_dropped aware_of_ucc wash_hands_before_cord_care agent_used_to_clean_cord_before_drop Hot_water_compress cotton_wool methylated_spirit_only chlorhexidine_gel_only use_CLGcorrect_LR use_CLGcorrect toooth_paste shea_butter metholatum herbs/local_concortion practice_outcome practice_outcomeLR  \
# 347          EKSUTH   M       >12 months                 10     Christianity    YORUBA       ADO      Urban           1    Tertiary  higher education              1    Tertiary           unspecified                     Unemployed                   0       unspecified          20         <=20yr       1          1        primi             0                Single                  Yes        11          >=8          Yes               1               PHC  Healthcare facility              1                    Yes              Private Hospital  Healthcare facility                1      3.5      2.5-3.9            I don’t know                             Cord clamp                                   7 - 14 days           Yes                         Yes                                    0                  0           0                      0                      1                 1            Yes            0           0          0                      0             Safe                  1
# 348          EKSUTH   M      7-12 months                8.5     Christianity    YORUBA       ADO      Urban           1    Tertiary  higher education              1    Tertiary         Civil servant       Formal sector employment                   1     Civil servant          32        31-40yr       2      2 - 4   mulitipara             1               Married                  Yes        10          >=8          Yes               1            EKSUTH  Healthcare facility              1                    Yes                        EKSUTH  Healthcare facility                1      2.8      2.5-3.9            I don’t know                             Cord clamp                                        <7 days          Yes                         Yes                                    0                  0           0                      1                      0                 0             No            0           0          0                      0             Safe                  1
# 349          EKSUTH   F       1-6 months                  5            Islam    YORUBA       ADO      Urban           1    Tertiary  higher education              1    Tertiary         Businesswoman  Informal sector/self employed                   1     Civil servant          23        21-30yr       1          1        primi             0               Married                  Yes         6        4 - 7          Yes               1  General hospital  Healthcare facility              1                    Yes              General Hospital  Healthcare facility                1                                  I don’t know                             Cord clamp                                        <7 days          Yes                         Yes                                    0                  0           0                      0                      1                 1            Yes            0           0          0                      0             Safe                  1
# 350          EKSUTH   M      7-12 months                  6            Islam    YORUBA       ADO      Urban           1    Tertiary  higher education              1    Tertiary         Businesswoman  Informal sector/self employed                   1     Civil servant          30        21-30yr       1          1        primi             0               Married                  Yes         6        4 - 7          Yes               1  General hospital  Healthcare facility              1                    Yes                       PHC/CHC  Healthcare facility                1      2.7      2.5-3.9                Scissors                             Cord clamp                                   7 - 14 days           Yes                         Yes                                    0                  0           0                      0                      1                 1            Yes            0           0          0                      0             Safe                  1
# 351          EKSUTH   M         <1 month                  4     Christianity     EBIRA       ADO      Urban           1    Tertiary  higher education              1    Tertiary  Full time house wife                      Homemaker                   0        Unemployed          27        21-30yr       1          1        primi             0             Separated                  Yes         7        4 - 7          Yes               1  General hospital  Healthcare facility              1                     No                       PHC/CHC  Healthcare facility                1        3      2.5-3.9            I don’t know                             Cord clamp                                       >14 days          Yes                         Yes                   Hot water compress                  1           0                      0                      0                 0             No            0           0          0                      0           Unsafe                  0
#
#     multi_agent freq_of_metspirit_use_in_a_day_cat freq_of_chlorhexidine_use_in_a_day_cat taught_on_chlorhexidine_app sure_using_chlorhexidine_correctly good_to_expose_cord_to_fresh_air good_to_expose_cord_to_keep_cord_in_diaper agent_applied_after_cord_drop safe_postsep_care safe_postsep_careLR multiple_agent_applied_after_cord_drop  Chlorhexidine gel                                         3 4                  5            6         7 duration_of_cord_care_practice_cat tiime_intended_to_stop_cat Post_sep_counsel Post_sep_counselLR who_told_you Previous_exp_source sister_source multiple_source Grandmother_source Other_Mothers_source Friends_source Healthcareworkers_source Healthcareworkers_source2cat Healthcareworkers_sourceLR Internet_source who_decides_how_to_care_for_the_child_cc self_decision_2cat self_decisionLR multiple          2            3.1 4.1 5.1
# 347          No                                                     2 or more times a day                         Yes                                Yes                               No                                         No                                             Yes                   1                                     No  Chlorhexidine gel                                                                                                            14 - 30 days                                                                                                0             0              No                  0                    0              1                        0                     Informal                          0               0
# 348          No                   >= 3 times a day                                                                                                                             Don’t know                                 Don’t know                                              No                   0                                    Yes                     Continue to clean with Methylated Spirit    Mentholatum/ Robb                                                 > 1 month                                          No                  0                                1             0             Yes                  1                    0              0                        0                     Informal                          0               0                                   Myself                Yes               1       No
# 349          No                                                                once a day                         Yes                                Yes                               No                                         No                                              No                   0                                     No                                                                                    Shea Butter                                    > 1 month                                          No                  0                                0             0              No                  1                    0              0                        0                     Informal                          0               0                                                          No               0       No             Mother-in-law
# 350          No                                                     2 or more times a day                         Yes                                Yes                               No                                         No                                              No                   0                                    Yes                     Continue to clean with Methylated Spirit                                    Vaseline                          > 1 month                                          No                  0                                0             0              No                  0                    0              0                        1                   Formal HCW                          1               0                                   Myself                Yes               1       No
# 351          No                   >= 3 times a day                                                                                                                                     No                                         No                                             Yes                   1                                     No  Chlorhexidine gel                                                                                                                > 1 month                                          No                  0                                0             0              No                  1                    0              0                        0                     Informal                          0               0                                                          No               0       No  My Mother

# %%
# Extract the two rows that pandas originally skipped (index 350 and 351)
corrupted_rows = raw_test.iloc[350:352]

# Print them out column by column, ignoring empty/nan fields, to see what's in them
for idx, row in corrupted_rows.iterrows():
    print(f"\n=== CRITICAL CHECK: DATA INSIDE ROW {idx+1} ===")
    valid_entries = {col: val for col, val in row.items() if str(val).strip() != ""}
    for col, val in list(valid_entries.items())[:10]: # Showing first 10 fields to keep it readable
        print(f"{col}: {val}")
# Out:
# === CRITICAL CHECK: DATA INSIDE ROW 351 ===
# health_facility: EKSUTH
# sex: M
# age_of_child_cat: 7-12 months
# child_weight_today: 6
# parents_religion: Islam
# ethnicity: YORUBA
# residence: ADO
# residenceL: Urban
# residenceLR: 1
# mother_hlfe: Tertiary
#
# === CRITICAL CHECK: DATA INSIDE ROW 352 ===
# health_facility: EKSUTH
# sex: M
# age_of_child_cat: <1 month
# child_weight_today: 4
# parents_religion: Christianity
# ethnicity: EBIRA
# residence: ADO
# residenceL: Urban
# residenceLR: 1
# mother_hlfe: Tertiary

# %%
data.head()
data.describe()
# Out:
#        child_weight_today  mother_hlfeLR  mother_occupationLR  mother_age      parity  parity_catLR    visit_no  adequate_ancLR  place_of_ancLR    child_bw  Hot_water_compress  cotton_wool  methylated_spirit_only  chlorhexidine_gel_only  use_CLGcorrect_LR  toooth_paste  shea_butter  metholatum  herbs/local_concortion  practice_outcomeLR  safe_postsep_careLR  Post_sep_counselLR  Previous_exp_source  sister_source  Grandmother_source  Other_Mothers_source  Friends_source  Healthcareworkers_source  Internet_source
# count          349.000000     350.000000           348.000000  350.000000  350.000000    350.000000  350.000000      350.000000      344.000000  295.000000          350.000000   350.000000              350.000000              350.000000         350.000000    350.000000   350.000000  350.000000              350.000000          345.000000           333.000000          311.000000           341.000000     341.000000          341.000000            341.000000      341.000000                341.000000       341.000000
# mean             5.677765       0.920000             0.867816   30.260000    2.082857      0.634286    5.468571        0.777143        0.909884    3.039085            0.142857     0.002857                0.680000                0.194286           0.151429      0.031429     0.062857    0.108571                0.008571            0.652174             0.561562            0.234727             0.269795       0.002933            0.272727              0.043988        0.043988                  0.507331         0.014663
# std              1.992747       0.271682             0.339178    5.431348    1.110767      0.482319    2.210391        0.416759        0.286765    0.509597            0.350428     0.053452                0.467144                0.396216           0.358979      0.174723     0.243053    0.311546                0.092316            0.476972             0.496942            0.424511             0.444505       0.054153            0.446016              0.205370        0.205370                  0.500681         0.120375
# min              1.930000       0.000000             0.000000   16.000000    1.000000      0.000000    2.000000        0.000000        0.000000    1.000000            0.000000     0.000000                0.000000                0.000000           0.000000      0.000000     0.000000    0.000000                0.000000            0.000000             0.000000            0.000000             0.000000       0.000000            0.000000              0.000000        0.000000                  0.000000         0.000000
# 25%              4.200000       1.000000             1.000000   27.000000    1.000000      0.000000    4.000000        1.000000        1.000000    2.700000            0.000000     0.000000                0.000000                0.000000           0.000000      0.000000     0.000000    0.000000                0.000000            0.000000             0.000000            0.000000             0.000000       0.000000            0.000000              0.000000        0.000000                  0.000000         0.000000
# 50%              5.300000       1.000000             1.000000   30.000000    2.000000      1.000000    5.000000        1.000000        1.000000    3.000000            0.000000     0.000000                1.000000                0.000000           0.000000      0.000000     0.000000    0.000000                0.000000            1.000000             1.000000            0.000000             0.000000       0.000000            0.000000              0.000000        0.000000                  1.000000         0.000000
# 75%              7.000000       1.000000             1.000000   34.000000    3.000000      1.000000    7.000000        1.000000        1.000000    3.400000            0.000000     0.000000                1.000000                0.000000           0.000000      0.000000     0.000000    0.000000                0.000000            1.000000             1.000000            0.000000             1.000000       0.000000            1.000000              0.000000        0.000000                  1.000000         0.000000
# max             14.000000       1.000000             1.000000   46.000000    7.000000      1.000000   11.000000        1.000000        1.000000    5.000000            1.000000     1.000000                1.000000                1.000000           1.000000      1.000000     1.000000    1.000000                1.000000            1.000000             1.000000            1.000000             1.000000       1.000000            1.000000              1.000000        1.000000                  1.000000         1.000000

# %%
# 1. Automatically grab all categorical columns
cat_cols = data.select_dtypes(include=['object', 'category']).columns
# 2. Loop through them and print counts and percentages
for col in cat_cols:
    print(f"--- {col} ---")
    
    # Calculate counts
    counts = data[col].value_counts()
    
    # Calculate percentages (normalize=True)
    percents = data[col].value_counts(normalize=True) * 100
    
    # Combine them into a small table for readability
    df_summary = pd.DataFrame({'Count': counts, 'Percentage (%)': percents})
    print(df_summary)
    print("\n") # Adds a space between columns
# Out:
# --- health_facility ---
#                  Count  Percentage (%)
# health_facility
# EKSUTH             241       68.857143
# IRE                 47       13.428571
# OKEILA              28        8.000000
# IGBEMO              24        6.857143
# PHC                  7        2.000000
# MISSION HOME         3        0.857143
#
#
# --- sex ---
#      Count  Percentage (%)
# sex
# F      190       54.131054
# M      161       45.868946
#
#
# --- age_of_child_cat ---
#                   Count  Percentage (%)
# age_of_child_cat
# 1-6 months          209       59.375000
# 7-12 months          78       22.159091
# <1 month             43       12.215909
# >12 months           22        6.250000
#
#
# --- parents_religion ---
#                   Count  Percentage (%)
# parents_religion
# Christianity        325       92.329545
# Islam                27        7.670455
#
#
# --- ethnicity ---
#            Count  Percentage (%)
# ethnicity
# YORUBA       315       89.488636
# IGBO          22        6.250000
# EBIRA          4        1.136364
# IGALA          3        0.852273
# EDO            2        0.568182
# HAUSA          2        0.568182
# ISOKO          1        0.284091
# IDOMA          1        0.284091
# BASSA          1        0.284091
# IGEDE          1        0.284091
#
#
# --- residence ---
#               Count  Percentage (%)
# residence
# ADO             267       76.068376
# IRE              50       14.245014
# IGBEMO           20        5.698006
# AFAO              3        0.854701
# OYE               2        0.569801
# AISEGBA           1        0.284900
# NIGER STATE       1        0.284900
# ILUMOBA           1        0.284900
# ABA OMORAN        1        0.284900
# IYIN              1        0.284900
# IGEDE             1        0.284900
# IGBEDE            1        0.284900
# PORT HARCOUT      1        0.284900
# OGUN              1        0.284900
#
#
# --- residenceL ---
#             Count  Percentage (%)
# residenceL
# Urban         270       76.923077
# Rural          81       23.076923
#
#
# --- mother_hlfe ---
#                      Count  Percentage (%)
# mother_hlfe
# Tertiary               226       64.204545
# SSCE                    98       27.840909
# JSS3                    15        4.261364
# Primary                 12        3.409091
# No formal Education      1        0.284091
#
#
# --- mother_hlfe_2cat ---
#                   Count  Percentage (%)
# mother_hlfe_2cat
# higher education    324       92.045455
# low education        28        7.954545
#
#
# --- father_hlfe ---
#                      Count  Percentage (%)
# father_hlfe
# Tertiary               262       74.431818
# SSCE                    82       23.295455
# Primary                  4        1.136364
# JSS3                     3        0.852273
# No formal Education      1        0.284091
#
#
# --- mother_occupation ---
#                               Count  Percentage (%)
# mother_occupation
# Businesswoman                   158       45.142857
# Civil servant                    41       11.714286
# Professional                     33        9.428571
# Private school teacher           31        8.857143
# Artisan                          26        7.428571
# Full time house wife             23        6.571429
# unspecified                      15        4.285714
# Teacher in government school     13        3.714286
# Farming                           7        2.000000
# clergy                            2        0.571429
# ANX NURSE                         1        0.285714
#
#
# --- mother_occupationL ---
#                                Count  Percentage (%)
# mother_occupationL
# Informal sector/self employed    186       53.142857
# Formal sector employment         118       33.714286
# Homemaker                         23        6.571429
# Unemployed                        23        6.571429
#
#
# --- father_occupation ---
#                            Count  Percentage (%)
# father_occupation
# Businessman                  101       28.774929
# Civil servant                 67       19.088319
# Artisan                       58       16.524217
# Professionals                 56       15.954416
# Driver                        19        5.413105
# Farming                       13        3.703704
# clergy                        11        3.133903
# Government school teacher      9        2.564103
# Private School Teacher         7        1.994302
# unspecified                    6        1.709402
# Unemployed                     3        0.854701
# Artsian                        1        0.284900
#
#
# --- mother_age_cat ---
#                 Count  Percentage (%)
# mother_age_cat
# 21-30yr           188       53.409091
# 31-40yr           139       39.488636
# <=20yr             13        3.693182
# >40yr              12        3.409091
#
#
# --- parity_cat ---
#             Count  Percentage (%)
# parity_cat
# 2 - 4         210       59.659091
# 1             129       36.647727
# >4             13        3.693182
#
#
# --- parity_2ca2t ---
#               Count  Percentage (%)
# parity_2ca2t
# mulitipara      223       63.352273
# primi           129       36.647727
#
#
# --- mother_marital_status ---
#                        Count  Percentage (%)
# mother_marital_status
# Married                  334       94.886364
# Single                    13        3.693182
# Separated                  5        1.420455
#
#
# --- attended_anc_in_preg ---
#                       Count  Percentage (%)
# attended_anc_in_preg
# Yes                     344       97.727273
# No                        8        2.272727
#
#
# --- visit_no_cat ---
#               Count  Percentage (%)
# visit_no_cat
# 4 - 7           198       56.250000
# 1 - 3            80       22.727273
# >=8              74       21.022727
#
#
# --- adequate_anc ---
#               Count  Percentage (%)
# adequate_anc
# Yes             272       77.272727
# No               80       22.727273
#
#
# --- place_of_anc ---
#                          Count  Percentage (%)
# place_of_anc
# EKSUTH                     147       42.485549
# PHC                         78       22.543353
# Private Hospital            51       14.739884
# General hospital            29        8.381503
# Mission home                24        6.936416
# TBA                          6        1.734104
# ABUAD                        2        0.578035
# General hospital EKSUTH      2        0.578035
# FMC LOKOJA                   1        0.289017
# AIRFORCE HOSP ABUJA          1        0.289017
# FMC ANNEX                    1        0.289017
# FETHI ANNEX                  1        0.289017
# CHURCH                       1        0.289017
# FETHI OYE                    1        0.289017
# FMC IDO                      1        0.289017
#
#
# --- place_of_anc_2_cat ---
#                          Count  Percentage (%)
# place_of_anc_2_cat
# Healthcare facility        315       91.040462
# Non healthcare facility     31        8.959538
#
#
# --- had_health_talk_on_ucc ---
#                         Count  Percentage (%)
# had_health_talk_on_ucc
# Yes                       263       78.742515
# No                         71       21.257485
#
#
# --- place_of_birth_of_index_child ---
#                                Count  Percentage (%)
# place_of_birth_of_index_child
# EKSUTH                           157       46.449704
# Private Hospital                  67       19.822485
# PHC/CHC                           52       15.384615
# Mission                           23        6.804734
# General Hospital                  13        3.846154
# Home                               9        2.662722
# TBA                                7        2.071006
# ABUAD                              2        0.591716
# FETHI                              2        0.591716
# Federal Hospital                   1        0.295858
# AIRFORCE HOSPITAL ABUJA            1        0.295858
# FMC ANNEX                          1        0.295858
# CHURCH                             1        0.295858
# FETHI OYE                          1        0.295858
# ON THE ROAD                        1        0.295858
#
#
# --- place_of_birth_2cat ---
#                          Count  Percentage (%)
# place_of_birth_2cat
# Healthcare facility        297       87.869822
# Non healthcare facility     41       12.130178
#
#
# --- child_bw_cat ---
#               Count  Percentage (%)
# child_bw_cat
# 2.5-3.9         257       86.531987
# <2.5             24        8.080808
# >=4              16        5.387205
#
#
# --- object_used_to_cut_cord ---
#                          Count  Percentage (%)
# object_used_to_cut_cord
# Surgical Blade             131       37.535817
# Scissors                   104       29.799427
# I don’t know               100       28.653295
# New Razor Blade             14        4.011461
#
#
# --- what_was_applied_to_the_cord_after_cut ---
#                                         Count  Percentage (%)
# what_was_applied_to_the_cord_after_cut
# Cord clamp                                298       87.390029
# Thread                                     41       12.023460
# Cord clamp,Thread                           2        0.586510
#
#
# --- thread_soaked_in_metspirit ---
#                             Count  Percentage (%)
# thread_soaked_in_metspirit
# Yes                            49       63.636364
# Don’t know                     18       23.376623
# No                             10       12.987013
#
#
# --- age_at_cord_dropped ---
#                      Count  Percentage (%)
# age_at_cord_dropped
# 7 - 14 days            182       54.984894
# <7 days                132       39.879154
# >14 days                17        5.135952
#
#
# --- aware_of_ucc ---
#               Count  Percentage (%)
# aware_of_ucc
# Yes             334       95.428571
# No               16        4.571429
#
#
# --- wash_hands_before_cord_care ---
#                              Count  Percentage (%)
# wash_hands_before_cord_care
# Yes                            311       88.857143
# No                              39       11.142857
#
#
# --- agent_used_to_clean_cord_before_drop ---
#                                       Count  Percentage (%)
# agent_used_to_clean_cord_before_drop
# 0                                       300       85.714286
# Hot water compress                       50       14.285714
#
#
# --- use_CLGcorrect ---
#                 Count  Percentage (%)
# use_CLGcorrect
# No                297       85.100287
# Yes                52       14.899713
#
#
# --- practice_outcome ---
#                   Count  Percentage (%)
# practice_outcome
# Safe                225       65.217391
# Unsafe              120       34.782609
#
#
# --- multi_agent ---
#              Count  Percentage (%)
# multi_agent
# No             268       77.906977
# Yes             76       22.093023
#
#
# --- freq_of_metspirit_use_in_a_day_cat ---
#                                     Count  Percentage (%)
# freq_of_metspirit_use_in_a_day_cat
# >= 3 times a day                      223       79.078014
# <3 times                               59       20.921986
#
#
# --- freq_of_chlorhexidine_use_in_a_day_cat ---
#                                         Count  Percentage (%)
# freq_of_chlorhexidine_use_in_a_day_cat
# 2 or more times a day                      74       74.747475
# once a day                                 25       25.252525
#
#
# --- taught_on_chlorhexidine_app ---
#                              Count  Percentage (%)
# taught_on_chlorhexidine_app
# Yes                             93       61.589404
# No                              58       38.410596
#
#
# --- sure_using_chlorhexidine_correctly ---
#                                     Count  Percentage (%)
# sure_using_chlorhexidine_correctly
# Yes                                    78       67.826087
# No                                     20       17.391304
# Don’t know                             17       14.782609
#
#
# --- good_to_expose_cord_to_fresh_air ---
#                                   Count  Percentage (%)
# good_to_expose_cord_to_fresh_air
# No                                  272       78.386167
# Yes                                  52       14.985591
# Don’t know                           23        6.628242
#
#
# --- good_to_expose_cord_to_keep_cord_in_diaper ---
#                                             Count  Percentage (%)
# good_to_expose_cord_to_keep_cord_in_diaper
# No                                            208       59.942363
# Yes                                           110       31.700288
# Don’t know                                     29        8.357349
#
#
# --- agent_applied_after_cord_drop ---
#                                Count  Percentage (%)
# agent_applied_after_cord_drop
# Nothing                           11       61.111111
# hot water compress                 5       27.777778
# toothpaste                         1        5.555556
# penicillin gel                     1        5.555556
#
#
# --- safe_postsep_care ---
#                    Count  Percentage (%)
# safe_postsep_care
# Yes                  188       56.119403
# No                   147       43.880597
#
#
# --- multiple_agent_applied_after_cord_drop ---
#                                         Count  Percentage (%)
# multiple_agent_applied_after_cord_drop
# No                                        284       87.116564
# Yes                                        42       12.883436
#
#
# --- Chlorhexidine gel ---
#                    Count  Percentage (%)
# Chlorhexidine gel
# Chlorhexidine gel     40           100.0
#
#
# --- 3 ---
#                                           Count  Percentage (%)
# 3
# Continue to clean with Methylated Spirit    171           100.0
#
#
# --- 4 ---
#                                             Count  Percentage (%)
# 4
# Methylated Spirit after hot water compress     49           100.0
#
#
# --- 5 ---
#                    Count  Percentage (%)
# 5
# Mentholatum/ Robb     53           100.0
#
#
# --- 6 ---
#              Count  Percentage (%)
# 6
# Shea Butter     48           100.0
#
#
# --- 7 ---
#           Count  Percentage (%)
# 7
# Vaseline      7           100.0
#
#
# --- duration_of_cord_care_practice_cat ---
#                                     Count  Percentage (%)
# duration_of_cord_care_practice_cat
# > 1 month                             121       58.737864
# 14 - 30 days                           63       30.582524
# < 14 days                              22       10.679612
#
#
# --- tiime_intended_to_stop_cat ---
#                             Count  Percentage (%)
# tiime_intended_to_stop_cat
# >= 3 months                   109       44.855967
# 1 - 2 months                   67       27.572016
# 14 - 30 days                   63       25.925926
# < 2 weeks                       4        1.646091
#
#
# --- Post_sep_counsel ---
#                   Count  Percentage (%)
# Post_sep_counsel
# No                  240       76.677316
# Yes                  73       23.322684
#
#
# --- who_told_you ---
#                    Count  Percentage (%)
# who_told_you
# grandmother            8       30.769231
# healthcare worker      7       26.923077
# mother                 5       19.230769
# mother in law          2        7.692308
# online                 1        3.846154
# family member          1        3.846154
# sister                 1        3.846154
# neighbours             1        3.846154
#
#
# --- multiple_source ---
#                  Count  Percentage (%)
# multiple_source
# No                 302       88.046647
# Yes                 41       11.953353
#
#
# --- Healthcareworkers_source2cat ---
#                               Count  Percentage (%)
# Healthcareworkers_source2cat
# Formal HCW                      173       50.437318
# Informal                        170       49.562682
#
#
# --- who_decides_how_to_care_for_the_child_cc ---
#                                           Count  Percentage (%)
# who_decides_how_to_care_for_the_child_cc
# Myself                                      201       99.014778
# husband                                       1        0.492611
# sister in law                                 1        0.492611
#
#
# --- self_decision_2cat ---
#                     Count  Percentage (%)
# self_decision_2cat
# Yes                   201        62.42236
# No                    121        37.57764
#
#
# --- multiple ---
#           Count  Percentage (%)
# multiple
# No          314       97.515528
# Yes           8        2.484472
#
#
# --- 2 ---
#            Count  Percentage (%)
# 2
# My Mother     72           100.0
#
#
# --- 3.1 ---
#                Count  Percentage (%)
# 3.1
# Mother-in-law     52           100.0
#
#
# --- 4.1 ---
#            Count  Percentage (%)
# 4.1
# My Sister      2           100.0
#
#
# --- 5.1 ---
#          Count  Percentage (%)
# 5.1
# Friends      1           100.0

# %%
from scipy.stats import chi2_contingency
import pandas as pd

# 1. Define your target variable and a list of factors you want to test
target = 'chlorhexidine_gel_only'
factors = ['mother_age_cat', 'parity_cat','mother_hlfe', 'mother_occupationL', 'mother_marital_status', 'parents_religion', 'residenceL', 'place_of_anc_2_cat', 'adequate_anc', 'had_health_talk_on_ucc', 'place_of_birth_2cat', 'Healthcareworkers_source2cat', 'self_decision_2cat'] # Add all your column names here

# 2. Loop through each factor
for factor in factors:
    print(f"\n" + "="*30)
    print(f"ANALYSIS: {factor} vs {target}")
    print("="*30)
    
    # Create the frequency table (Counts)
    ct_counts = pd.crosstab(data[factor], data[target])
    
    # Create the percentage table (Row-wise percentages)
    ct_percent = pd.crosstab(data[factor], data[target], normalize='index') * 100
    
    # Perform the Chi-Square Test
    chi2, p, dof, expected = chi2_contingency(ct_counts)
    
    # Display Results
    print("\n--- Frequency Count Table (Counts) ---")
    print(ct_counts)
    print("--- Percentage Table (Row %) ---")
    print(ct_percent.round(2))
    
    print("\n--- Chi-Square Test Results ---")
    print(f"Chi-Square Statistic: {chi2:.4f}")
    print(f"P-value: {p:.4f}")
    print(f"Degrees of Freedom: {dof}")
    
    # Quick Interpretation
    alpha = 0.05
    if p < alpha:
        print("\nResult: Statistically significant (Reject H0)")
    else:
        print("\nResult: Not statistically significant (Fail to reject H0)")
# Out:
# ==============================
# ANALYSIS: mother_age_cat vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only  0.0  1.0
# mother_age_cat
# 21-30yr                 147   40
# 31-40yr                 112   27
# <=20yr                   12    1
# >40yr                    11    0
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only     0.0    1.0
# mother_age_cat
# 21-30yr                  78.61  21.39
# 31-40yr                  80.58  19.42
# <=20yr                   92.31   7.69
# >40yr                   100.00   0.00
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 4.2561
# P-value: 0.2351
# Degrees of Freedom: 3
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: parity_cat vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only  0.0  1.0
# parity_cat
# 1                       102   26
# 2 - 4                   167   42
# >4                       13    0
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only     0.0    1.0
# parity_cat
# 1                        79.69  20.31
# 2 - 4                    79.90  20.10
# >4                      100.00   0.00
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 3.2581
# P-value: 0.1961
# Degrees of Freedom: 2
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: mother_hlfe vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only  0.0  1.0
# mother_hlfe
# JSS3                     14    1
# No formal Education       1    0
# Primary                  12    0
# SSCE                     87   11
# Tertiary                168   56
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only     0.0    1.0
# mother_hlfe
# JSS3                     93.33   6.67
# No formal Education     100.00   0.00
# Primary                 100.00   0.00
# SSCE                     88.78  11.22
# Tertiary                 75.00  25.00
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 13.3509
# P-value: 0.0097
# Degrees of Freedom: 4
#
# Result: Statistically significant (Reject H0)
#
# ==============================
# ANALYSIS: mother_occupationL vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only         0.0  1.0
# mother_occupationL
# Formal sector employment        92   26
# Homemaker                       20    3
# Informal sector/self employed  149   35
# Unemployed                      19    4
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only           0.0    1.0
# mother_occupationL
# Formal sector employment       77.97  22.03
# Homemaker                      86.96  13.04
# Informal sector/self employed  80.98  19.02
# Unemployed                     82.61  17.39
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 1.1832
# P-value: 0.7570
# Degrees of Freedom: 3
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: mother_marital_status vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only  0.0  1.0
# mother_marital_status
# Married                 266   66
# Separated                 5    0
# Single                   11    2
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only     0.0    1.0
# mother_marital_status
# Married                  80.12  19.88
# Separated               100.00   0.00
# Single                   84.62  15.38
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 1.3846
# P-value: 0.5004
# Degrees of Freedom: 2
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: parents_religion vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only  0.0  1.0
# parents_religion
# Christianity            260   63
# Islam                    22    5
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only    0.0    1.0
# parents_religion
# Christianity            80.50  19.50
# Islam                   81.48  18.52
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.0000
# P-value: 1.0000
# Degrees of Freedom: 1
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: residenceL vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only  0.0  1.0
# residenceL
# Rural                    76    5
# Urban                   205   63
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only    0.0    1.0
# residenceL
# Rural                   93.83   6.17
# Urban                   76.49  23.51
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 10.8347
# P-value: 0.0010
# Degrees of Freedom: 1
#
# Result: Statistically significant (Reject H0)
#
# ==============================
# ANALYSIS: place_of_anc_2_cat vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only   0.0  1.0
# place_of_anc_2_cat
# Healthcare facility      249   64
# Non healthcare facility   27    4
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only     0.0    1.0
# place_of_anc_2_cat
# Healthcare facility      79.55  20.45
# Non healthcare facility  87.10  12.90
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.5924
# P-value: 0.4415
# Degrees of Freedom: 1
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: adequate_anc vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only  0.0  1.0
# adequate_anc
# No                       65   13
# Yes                     217   55
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only    0.0    1.0
# adequate_anc
# No                      83.33  16.67
# Yes                     79.78  20.22
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.2884
# P-value: 0.5912
# Degrees of Freedom: 1
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: had_health_talk_on_ucc vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only  0.0  1.0
# had_health_talk_on_ucc
# No                       59   11
# Yes                     207   55
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only    0.0    1.0
# had_health_talk_on_ucc
# No                      84.29  15.71
# Yes                     79.01  20.99
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 0.6632
# P-value: 0.4154
# Degrees of Freedom: 1
#
# Result: Not statistically significant (Fail to reject H0)
#
# ==============================
# ANALYSIS: place_of_birth_2cat vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only   0.0  1.0
# place_of_birth_2cat
# Healthcare facility      232   63
# Non healthcare facility   39    2
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only     0.0    1.0
# place_of_birth_2cat
# Healthcare facility      78.64  21.36
# Non healthcare facility  95.12   4.88
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 5.2526
# P-value: 0.0219
# Degrees of Freedom: 1
#
# Result: Statistically significant (Reject H0)
#
# ==============================
# ANALYSIS: Healthcareworkers_source2cat vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only        0.0  1.0
# Healthcareworkers_source2cat
# Formal HCW                    130   43
# Informal                      145   23
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only          0.0    1.0
# Healthcareworkers_source2cat
# Formal HCW                    75.14  24.86
# Informal                      86.31  13.69
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 6.1104
# P-value: 0.0134
# Degrees of Freedom: 1
#
# Result: Statistically significant (Reject H0)
#
# ==============================
# ANALYSIS: self_decision_2cat vs chlorhexidine_gel_only
# ==============================
#
# --- Frequency Count Table (Counts) ---
# chlorhexidine_gel_only  0.0  1.0
# self_decision_2cat
# No                      107   13
# Yes                     156   44
# --- Percentage Table (Row %) ---
# chlorhexidine_gel_only    0.0    1.0
# self_decision_2cat
# No                      89.17  10.83
# Yes                     78.00  22.00
#
# --- Chi-Square Test Results ---
# Chi-Square Statistic: 5.6482
# P-value: 0.0175
# Degrees of Freedom: 1
#
# Result: Statistically significant (Reject H0)

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np

# 1. Load Data
df = pd.read_excel("dataset_cord_care_analyze.xlsx")

# 2. Clean/Verify Data Types & Handle Missing Values
df = df.dropna(subset=['chlorhexidine_gel_only'])
df['chlorhexidine_gel_only'] = df['chlorhexidine_gel_only'].astype(int)
df['mother_age'] = pd.to_numeric(df['mother_age'], errors='coerce')

# Define predictors exactly as they appear in your formula definitions
predictors = [
    "C(Healthcareworkers_sourceLR)",
    "C(self_decisionLR)",
    "C(mother_hlfeLR)",
    "C(place_of_birthLR)",
    "C(residenceLR)",
    "mother_age"
]

# --- STEP A: CALCULATE CRUDE ODDS RATIOS (UNIVARIATE) ---
crude_results = []

for pred in predictors:
    # Fit simple logistic regression for a single predictor
    uni_formula = f"chlorhexidine_gel_only ~ {pred}"
    try:
        uni_model = smf.logit(uni_formula, data=df).fit(disp=0)
        
        # Extract odds, confidence intervals, and p-values
        or_val = np.exp(uni_model.params)
        ci_val = np.exp(uni_model.conf_int())
        p_val = uni_model.pvalues
        
        # Combine into a temporary dataframe for this predictor
        pred_df = pd.DataFrame({
            'cOR': or_val,
            'cOR_Lower': ci_val[0],
            'cOR_Upper': ci_val[1],
            'Crude p-value': p_val
        })
        crude_results.append(pred_df)
    except Exception as e:
        print(f"Skipping crude calculation for {pred} due to error: {e}")

# Combine all crude summaries together (excluding the individual intercept rows)
df_crude = pd.concat(crude_results)
df_crude = df_crude[~df_crude.index.str.contains('Intercept')]
import pandas as pd

# --- STEP B: CALCULATE ADJUSTED ODDS RATIOS (MULTIVARIABLE) ---
formula = "chlorhexidine_gel_only ~ " + " + ".join(predictors)
model_mv = smf.logit(formula, data=df).fit()

model_odds = np.exp(model_mv.params)
conf_int = np.exp(model_mv.conf_int())

df_aor = pd.DataFrame({
    'aOR': model_odds,
    'aOR_Lower': conf_int[0],
    'aOR_Upper': conf_int[1],
    'Adjusted p-value': model_mv.pvalues
})

# --- STEP C: MERGE CRUDE AND ADJUSTED TABLES TOGETHER ---
df_final = df_aor.join(df_crude, how='left')

# Reorder columns logically for publication
final_column_order = [
    'cOR', 'cOR_Lower', 'cOR_Upper', 'Crude p-value',
    'aOR', 'aOR_Lower', 'aOR_Upper', 'Adjusted p-value'
]
df_final = df_final.reindex(columns=final_column_order)

# --- FORCE PANDAS TO PRINT IN A SINGLE WIDE LAYOUT ---
pd.set_option('display.width', 1000)       # Tells pandas your screen is very wide
pd.set_option('display.max_columns', None) # Don't truncate columns with "..."

print("\n" + "="*85)
print("FINAL MERGED LOGISTIC REGRESSION TABLE")
print("="*85)
print(df_final.round(3))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.428609
#          Iterations 8
#
# =====================================================================================
# FINAL MERGED LOGISTIC REGRESSION TABLE
# =====================================================================================
#                                         cOR  cOR_Lower  cOR_Upper  Crude p-value    aOR  aOR_Lower  aOR_Upper  Adjusted p-value
# Intercept                               NaN        NaN        NaN            NaN  0.059      0.003      1.168             0.063
# C(Healthcareworkers_sourceLR)[T.1.0]  2.085      1.192      3.647          0.010  1.234      0.645      2.363             0.525
# C(self_decisionLR)[T.1.0]             2.321      1.193      4.518          0.013  1.679      0.803      3.508             0.168
# C(mother_hlfeLR)[T.1]                 7.094      0.947     53.157          0.057  2.162      0.237     19.765             0.495
# C(place_of_birthLR)[T.1.0]            5.295      1.245     22.530          0.024  4.934      0.600     40.548             0.137
# C(residenceLR)[T.1.0]                 4.671      1.810     12.053          0.001  2.807      0.991      7.952             0.052
# mother_age                            0.979      0.932      1.029          0.402  0.927      0.869      0.990             0.023

# %%
# !pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\ajayi\anaconda3\lib\site-packages (from missingno) (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\ajayi\anaconda3\lib\site-packages (from missingno) (3.10.6)
# Requirement already satisfied: scipy in c:\users\ajayi\anaconda3\lib\site-packages (from missingno) (1.16.3)
# Requirement already satisfied: seaborn in c:\users\ajayi\anaconda3\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajayi\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajayi\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajayi\anaconda3\lib\site-packages (from matplotlib->missingno) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajayi\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajayi\anaconda3\lib\site-packages (from matplotlib->missingno) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ajayi\anaconda3\lib\site-packages (from matplotlib->missingno) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajayi\anaconda3\lib\site-packages (from matplotlib->missingno) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajayi\anaconda3\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ajayi\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ajayi\anaconda3\lib\site-packages (from seaborn->missingno) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajayi\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajayi\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2

# %%
import missingno as msno
import matplotlib.pyplot as plt

# Visualizes where the holes in your dataset are
msno.matrix(data)
plt.show()

# Visualizes if missingness in one factor correlates with missingness in another
msno.heatmap(data)
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np

# 1. Load Data
df = pd.read_excel("dataset_cord_care_analyze.xlsx")

# 2. Clean/Verify Data Types & Handle Missing Values
df = df.dropna(subset=['chlorhexidine_gel_only'])
df['chlorhexidine_gel_only'] = df['chlorhexidine_gel_only'].astype(int)
df['mother_age'] = pd.to_numeric(df['mother_age'], errors='coerce')

# Define predictors exactly as they appear in your formula definitions
predictors = [
    "C(Healthcareworkers_sourceLR)",
    "C(mother_hlfeLR)",
    "C(place_of_birthLR)",
    "C(residenceLR)",
    "mother_age"
]

# --- STEP A: CALCULATE CRUDE ODDS RATIOS (UNIVARIATE) ---
crude_results = []

for pred in predictors:
    # Fit simple logistic regression for a single predictor
    uni_formula = f"chlorhexidine_gel_only ~ {pred}"
    try:
        uni_model = smf.logit(uni_formula, data=df).fit(disp=0)
        
        # Extract odds, confidence intervals, and p-values
        or_val = np.exp(uni_model.params)
        ci_val = np.exp(uni_model.conf_int())
        p_val = uni_model.pvalues
        
        # Combine into a temporary dataframe for this predictor
        pred_df = pd.DataFrame({
            'cOR': or_val,
            'cOR_Lower': ci_val[0],
            'cOR_Upper': ci_val[1],
            'Crude p-value': p_val
        })
        crude_results.append(pred_df)
    except Exception as e:
        print(f"Skipping crude calculation for {pred} due to error: {e}")

# Combine all crude summaries together (excluding the individual intercept rows)
df_crude = pd.concat(crude_results)
df_crude = df_crude[~df_crude.index.str.contains('Intercept')]
import pandas as pd

# --- STEP B: CALCULATE ADJUSTED ODDS RATIOS (MULTIVARIABLE) ---
formula = "chlorhexidine_gel_only ~ " + " + ".join(predictors)
model_mv = smf.logit(formula, data=df).fit()

model_odds = np.exp(model_mv.params)
conf_int = np.exp(model_mv.conf_int())

df_aor = pd.DataFrame({
    'aOR': model_odds,
    'aOR_Lower': conf_int[0],
    'aOR_Upper': conf_int[1],
    'Adjusted p-value': model_mv.pvalues
})

# --- STEP C: MERGE CRUDE AND ADJUSTED TABLES TOGETHER ---
df_final = df_aor.join(df_crude, how='left')

# Reorder columns logically for publication
final_column_order = [
    'cOR', 'cOR_Lower', 'cOR_Upper', 'Crude p-value',
    'aOR', 'aOR_Lower', 'aOR_Upper', 'Adjusted p-value'
]
df_final = df_final.reindex(columns=final_column_order)

# --- FORCE PANDAS TO PRINT IN A SINGLE WIDE LAYOUT ---
pd.set_option('display.width', 1000)       # Tells pandas your screen is very wide
pd.set_option('display.max_columns', None) # Don't truncate columns with "..."

print("\n" + "="*85)
print("FINAL MERGED LOGISTIC REGRESSION TABLE")
print("="*85)
print(df_final.round(3))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.453700
#          Iterations 8
#
# =====================================================================================
# FINAL MERGED LOGISTIC REGRESSION TABLE
# =====================================================================================
#                                         cOR  cOR_Lower  cOR_Upper  Crude p-value    aOR  aOR_Lower  aOR_Upper  Adjusted p-value
# Intercept                               NaN        NaN        NaN            NaN  0.042      0.002      0.797             0.035
# C(Healthcareworkers_sourceLR)[T.1.0]  2.085      1.192      3.647          0.010  1.427      0.790      2.575             0.238
# C(mother_hlfeLR)[T.1]                 7.094      0.947     53.157          0.057  2.031      0.226     18.228             0.527
# C(place_of_birthLR)[T.1.0]            5.295      1.245     22.530          0.024  5.631      0.690     45.921             0.107
# C(residenceLR)[T.1.0]                 4.671      1.810     12.053          0.001  3.418      1.237      9.448             0.018
# mother_age                            0.979      0.932      1.029          0.402  0.942      0.888      0.999             0.046

# %%
import warnings
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tools.sm_exceptions import ConvergenceWarning

# Suppress visual convergence warnings for cleaner output
warnings.simplefilter("ignore", ConvergenceWarning)

# ==========================================
# STEP 1: LOAD AND CLEAN DATA
# ==========================================
# Load the dataset
df = pd.read_excel("dataset_cord_care_analyze.xlsx")

# Drop rows where the target variable itself is missing
df = df.dropna(subset=['chlorhexidine_gel_only'])

# Clean and verify data types
df['chlorhexidine_gel_only'] = df['chlorhexidine_gel_only'].astype(int)
df['mother_age'] = pd.to_numeric(df['mother_age'], errors='coerce')

# Handle missing data for categorical predictors by filling NaNs with a 'Missing' label
categorical_factors = [
    'self_decisionLR', 
    'Healthcareworkers_sourceLR', 
    'mother_hlfeLR', 
    'place_of_birthLR', 
    'residenceLR'
]

for factor in categorical_factors:
    df[factor] = df[factor].fillna('Missing')

# Define predictors exactly as they should appear in the Patsy formula definitions
predictors = [
    "C(Healthcareworkers_sourceLR)",
    "C(self_decisionLR)",
    "C(mother_hlfeLR)",
    "C(place_of_birthLR)",
    "C(residenceLR)",
    "mother_age"
]

# ==========================================
# STEP 2: CALCULATE CRUDE ODDS RATIOS (UNIVARIATE)
# ==========================================
crude_results = []

for pred in predictors:
    # Fit simple Logistic regression for a single predictor
    uni_formula = f"chlorhexidine_gel_only ~ {pred}"
    try:
        uni_model = smf.logit(uni_formula, data=df).fit(disp=0)
        
        # Extract odds, confidence intervals, and p-values
        or_val = np.exp(uni_model.params)
        ci_val = np.exp(uni_model.conf_int())
        p_val = uni_model.pvalues
        
        # Combine into a temporary dataframe for this predictor
        pred_df = pd.DataFrame({
            'cOR': or_val,
            'cOR_Lower': ci_val[0],
            'cOR_Upper': ci_val[1],
            'Crude p-value': p_val
        })
        crude_results.append(pred_df)
        
    except Exception as e:
        print(f"Skipping crude calculation for {pred} due to error: {e}")

# Combine all crude summaries together and drop Intercept rows
df_crude = pd.concat(crude_results)
df_crude = df_crude.drop('Intercept', errors='ignore')

# ==========================================
# STEP 3: CALCULATE ADJUSTED ODDS RATIOS (MULTIVARIABLE)
# ==========================================
# Construct the full multivariable formula string cleanly
formula = "chlorhexidine_gel_only ~ " + " + ".join(predictors)
model_mv = smf.logit(formula, data=df).fit()

model_odds = np.exp(model_mv.params)
conf_int = np.exp(model_mv.conf_int())

df_aor = pd.DataFrame({
    'aOR': model_odds,
    'aOR_Lower': conf_int[0],
    'aOR_Upper': conf_int[1],
    'Adjusted p-value': model_mv.pvalues
})

# Drop the Intercept row from the multivariable dataframe
df_aor = df_aor.drop('Intercept', errors='ignore')

# ==========================================
# STEP 4: MERGE TABLES AND FORMAT OUTPUT
# ==========================================
# Explicit outer merge on indices ensures perfect row-by-row alignment
df_final = df_aor.merge(df_crude, left_index=True, right_index=True, how='outer')

# Reorder columns logically for medical journal publication
final_column_order = [
    'cOR', 'cOR_Lower', 'cOR_Upper', 'Crude p-value',
    'aOR', 'aOR_Lower', 'aOR_Upper', 'Adjusted p-value'
]
df_final = df_final.reindex(columns=final_column_order)

# Force pandas to print in a single wide layout without truncating
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)

print("\n" + "="*95)
print("FINAL MERGED LOGISTIC REGRESSION TABLE (CRUDE vs ADJUSTED ODDS RATIOS)")
print("="*95)
print(df_final.round(3))
# Out:
# C:\Users\ajayi\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: overflow encountered in exp
#   result = func(self.values, **kwargs)
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.443871
#          Iterations: 35
# C:\Users\ajayi\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: overflow encountered in exp
#   result = func(self.values, **kwargs)
# ===============================================================================================
# FINAL MERGED LOGISTIC REGRESSION TABLE (CRUDE vs ADJUSTED ODDS RATIOS)
# ===============================================================================================
#                                             cOR  cOR_Lower  cOR_Upper  Crude p-value    aOR  aOR_Lower  aOR_Upper  Adjusted p-value
# C(Healthcareworkers_sourceLR)[T.1.0]      2.085      1.192      3.647          0.010  1.403      0.770      2.557             0.269
# C(Healthcareworkers_sourceLR)[T.Missing]  1.801      0.352      9.211          0.480  1.487      0.273      8.108             0.646
# C(mother_hlfeLR)[T.1]                     7.094      0.947     53.157          0.057  2.126      0.237     19.092             0.500
# C(place_of_birthLR)[T.1.0]                5.295      1.245     22.530          0.024  2.774      0.563     13.652             0.210
# C(place_of_birthLR)[T.Missing]            5.318      0.787     35.922          0.086  3.090      0.374     25.556             0.295
# C(residenceLR)[T.1.0]                     4.671      1.810     12.053          0.001  3.693      1.336     10.203             0.012
# C(residenceLR)[T.Missing]                 0.000      0.000        inf          1.000  0.000      0.000        inf             0.999
# C(self_decisionLR)[T.1.0]                 2.321      1.193      4.518          0.013  1.944      0.942      4.011             0.072
# C(self_decisionLR)[T.Missing]             4.765      1.862     12.194          0.001  3.511      1.297      9.508             0.013
# mother_age                                0.979      0.932      1.029          0.402  0.929      0.876      0.986             0.015

# %%
import warnings
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tools.sm_exceptions import ConvergenceWarning

# Suppress visual convergence warnings for cleaner output
warnings.simplefilter("ignore", ConvergenceWarning)

# ==========================================
# STEP 1: LOAD AND CLEAN DATA
# ==========================================
# Load the dataset
df = pd.read_excel("dataset_cord_care_analyze.xlsx")

# Drop rows where the target variable itself is missing
df = df.dropna(subset=['chlorhexidine_gel_only'])

# Clean and verify data types
df['chlorhexidine_gel_only'] = df['chlorhexidine_gel_only'].astype(int)
df['mother_age'] = pd.to_numeric(df['mother_age'], errors='coerce')

# Handle missing data for categorical predictors by filling NaNs with a 'Missing' label
categorical_factors = [
    'self_decisionLR', 
    'Healthcareworkers_sourceLR', 
    'mother_hlfeLR', 
    'place_of_birthLR', 
    'residenceLR'
]

for factor in categorical_factors:
    df[factor] = df[factor].fillna('Missing')

# FIX: Filter out perfect separation rows in residenceLR to avoid infinite confidence intervals
df = df[df['residenceLR'] != 'Missing']

# Define predictors exactly as they should appear in the Patsy formula definitions
predictors = [
    "C(Healthcareworkers_sourceLR)",
    "C(self_decisionLR)",
    "C(mother_hlfeLR)",
    "C(place_of_birthLR)",
    "C(residenceLR)",
    "mother_age"
]

# ==========================================
# STEP 2: CALCULATE CRUDE ODDS RATIOS (UNIVARIATE)
# ==========================================
crude_results = []

for pred in predictors:
    # Fit simple Logistic regression for a single predictor
    uni_formula = f"chlorhexidine_gel_only ~ {pred}"
    try:
        uni_model = smf.logit(uni_formula, data=df).fit(disp=0)
        
        # Extract odds, confidence intervals, and p-values
        or_val = np.exp(uni_model.params)
        ci_val = np.exp(uni_model.conf_int())
        p_val = uni_model.pvalues
        
        # Combine into a temporary dataframe for this predictor
        pred_df = pd.DataFrame({
            'cOR': or_val,
            'cOR_Lower': ci_val[0],
            'cOR_Upper': ci_val[1],
            'Crude p-value': p_val
        })
        crude_results.append(pred_df)
        
    except Exception as e:
        print(f"Skipping crude calculation for {pred} due to error: {e}")

# Combine all crude summaries together and drop Intercept rows
df_crude = pd.concat(crude_results)
df_crude = df_crude.drop('Intercept', errors='ignore')

# ==========================================
# STEP 3: CALCULATE ADJUSTED ODDS RATIOS (MULTIVARIABLE)
# ==========================================
# Construct the full multivariable formula string cleanly
formula = "chlorhexidine_gel_only ~ " + " + ".join(predictors)
model_mv = smf.logit(formula, data=df).fit()

model_odds = np.exp(model_mv.params)
conf_int = np.exp(model_mv.conf_int())

df_aor = pd.DataFrame({
    'aOR': model_odds,
    'aOR_Lower': conf_int[0],
    'aOR_Upper': conf_int[1],
    'Adjusted p-value': model_mv.pvalues
})

# Drop the Intercept row from the multivariable dataframe
df_aor = df_aor.drop('Intercept', errors='ignore')

# ==========================================
# STEP 4: MERGE TABLES AND FORMAT OUTPUT
# ==========================================
# Explicit outer merge on indices ensures perfect row-by-row alignment
df_final = df_aor.merge(df_crude, left_index=True, right_index=True, how='outer')

# Reorder columns logically for medical journal publication
final_column_order = [
    'cOR', 'cOR_Lower', 'cOR_Upper', 'Crude p-value',
    'aOR', 'aOR_Lower', 'aOR_Upper', 'Adjusted p-value'
]
df_final = df_final.reindex(columns=final_column_order)

# Force pandas to print in a single wide layout without truncating
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)
print("\n" + "="*95)
print("FINAL MERGED LOGISTIC REGRESSION TABLE (CRUDE vs ADJUSTED ODDS RATIOS)")
print("="*95)
print(df_final.round(3))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.445143
#          Iterations 7
#
# ===============================================================================================
# FINAL MERGED LOGISTIC REGRESSION TABLE (CRUDE vs ADJUSTED ODDS RATIOS)
# ===============================================================================================
#                                             cOR  cOR_Lower  cOR_Upper  Crude p-value    aOR  aOR_Lower  aOR_Upper  Adjusted p-value
# C(Healthcareworkers_sourceLR)[T.1.0]      2.071      1.184      3.622          0.011  1.403      0.770      2.557             0.269
# C(Healthcareworkers_sourceLR)[T.Missing]  1.789      0.350      9.148          0.485  1.487      0.273      8.108             0.646
# C(mother_hlfeLR)[T.1]                     6.831      0.910     51.258          0.062  2.126      0.237     19.092             0.500
# C(place_of_birthLR)[T.1.0]                5.318      1.250     22.628          0.024  2.774      0.563     13.652             0.210
# C(place_of_birthLR)[T.Missing]            5.318      0.787     35.922          0.086  3.090      0.374     25.556             0.295
# C(residenceLR)[T.1.0]                     4.671      1.810     12.053          0.001  3.693      1.336     10.203             0.012
# C(self_decisionLR)[T.1.0]                 2.300      1.181      4.477          0.014  1.944      0.942      4.011             0.072
# C(self_decisionLR)[T.Missing]             4.721      1.844     12.082          0.001  3.511      1.297      9.508             0.013
# mother_age                                0.978      0.931      1.028          0.379  0.929      0.876      0.986             0.015
