# %%
# !pip install pandas openpyxl biopython requests rapidfuzz pymupdf pdfplumber openai tqdm
# Out:
# Requirement already satisfied: pandas in c:\users\ajayi\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: openpyxl in c:\users\ajayi\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: biopython in c:\users\ajayi\anaconda3\lib\site-packages (1.87)
# Requirement already satisfied: requests in c:\users\ajayi\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: rapidfuzz in c:\users\ajayi\anaconda3\lib\site-packages (3.14.5)
# Requirement already satisfied: pymupdf in c:\users\ajayi\anaconda3\lib\site-packages (1.27.2.3)
# Requirement already satisfied: pdfplumber in c:\users\ajayi\anaconda3\lib\site-packages (0.11.9)
# Requirement already satisfied: openai in c:\users\ajayi\anaconda3\lib\site-packages (2.41.1)
# Requirement already satisfied: tqdm in c:\users\ajayi\anaconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ajayi\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajayi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajayi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajayi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\ajayi\anaconda3\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ajayi\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajayi\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajayi\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajayi\anaconda3\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: pdfminer.six==20251230 in c:\users\ajayi\anaconda3\lib\site-packages (from pdfplumber) (20251230)
# Requirement already satisfied: Pillow>=9.1 in c:\users\ajayi\anaconda3\lib\site-packages (from pdfplumber) (12.0.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\ajayi\anaconda3\lib\site-packages (from pdfplumber) (5.9.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\ajayi\anaconda3\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (46.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ajayi\anaconda3\lib\site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ajayi\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ajayi\anaconda3\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\ajayi\anaconda3\lib\site-packages (from openai) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\ajayi\anaconda3\lib\site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in c:\users\ajayi\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\ajayi\anaconda3\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ajayi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ajayi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ajayi\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ajayi\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ajayi\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\ajayi\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\ajayi\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ajayi\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.23)
# Requirement already satisfied: six>=1.5 in c:\users\ajayi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import os
import pandas as pd
from Bio import Entrez
from rapidfuzz import fuzz
import ollama
from tqdm import tqdm

# ==========================================
# CONFIGURATION
# ==========================================
Entrez.email = "ajayitemitopejeremiah@gmail.com"  # Replace with your email
SEARCH_QUERY = "machine learning AND melanoma diagnosis"
MAX_RESULTS = 50  # Adjust based on your needs

INCLUSION_CRITERIA = """
1. The study must use Machine Learning or Deep Learning techniques.
2. The study must focus on diagnosing Melanoma skin cancer.
3. The study must use human clinical images or dermoscopy data.
Exclude any general reviews, editorials, or animal-only trials.
"""

# ==========================================
# STEP 1: FETCH DATA FROM PUBMED
# ==========================================
def fetch_pubmed_papers(query, max_results):
    print(f"🔍 Searching PubMed for: '{query}'...")
    handle = Entrez.esearch(db="pubmed", term=query, retmax=max_results)
    record = Entrez.read(handle)
    handle.close()
    id_list = record["IdList"]
    
    if not id_list:
        print("❌ No papers found for this query.")
        return pd.DataFrame()

    print(f"📥 Fetching metadata for {len(id_list)} papers...")
    handle = Entrez.efetch(db="pubmed", id=",".join(id_list), retmode="xml")
    records = Entrez.read(handle)
    handle.close()
    
    articles = []
    for article in records['PubmedArticle']:
        try:
            title = article['MedlineCitation']['Article']['ArticleTitle']
            
            # Extract Abstract safely
            abstract_text = article['MedlineCitation']['Article']['Abstract']['AbstractText']
            abstract = " ".join(abstract_text) if isinstance(abstract_text, list) else str(abstract_text)
            
            # Extract DOI safely
            doi = "N/A"
            for id_elem in article['PubmedArticle']['PubmedData']['ArticleIdList']:
                if id_elem.attributes.get('IdType') == 'doi':
                    doi = str(id_elem)
                    break
                    
            articles.append({"Title": title, "Abstract": abstract, "DOI": doi})
        except (KeyError, IndexError):
            continue
            
    return pd.DataFrame(articles)

# ==========================================
# STEP 2: SMART DEDUPLICATION
# ==========================================
def deduplicate_papers(df, similarity_threshold=90):
    print("🧹 Starting deduplication process...")
    initial_count = len(df)
    
    # Remove exact DOI matches
    df = df.drop_duplicates(subset=['DOI'])
    
    # Remove fuzzy title matches
    titles = df['Title'].tolist()
    indices_to_drop = []
    
    for i in range(len(titles)):
        for j in range(i + 1, len(titles)):
            if fuzz.ratio(titles[i].lower(), titles[j].lower()) > similarity_threshold:
                indices_to_drop.append(df.index[j])
                
    df_cleaned = df.drop(index=list(set(indices_to_drop)))
    print(f"✅ Deduplication finished. Removed {initial_count - len(df_cleaned)} duplicates.")
    return df_cleaned

# ==========================================
# STEP 3: AI SCREENING (LOCAL OLLAMA LLM)
# ==========================================
def screen_abstract_with_ai(title, abstract, criteria):
    prompt = f"""
    You are an expert medical researcher conducting a Systematic Literature Review.
    
    Strict Eligibility Criteria:
    {criteria}
    
    Evaluate this paper:
    Title: {title}
    Abstract: {abstract}
    
    Does this paper satisfy all inclusion criteria? 
    Respond with exactly ONE word: either 'INCLUDE' or 'EXCLUDE'. Do not output anything else.
    """
    try:
        response = ollama.generate(model='llama3', prompt=prompt)
        decision = response['response'].strip().upper()
        # Clean up any unexpected LLM conversational text
        if "INCLUDE" in decision:
            return "INCLUDE"
        return "EXCLUDE"
    except Exception as e:
        return f"ERROR ({str(e)})"
