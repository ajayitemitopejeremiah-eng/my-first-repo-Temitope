# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in C:\Users\ajayi\AppData\Local\Programs\Python\Python313\Lib\site-packages (12.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib.request

# This dictionary maps the exact filenames your design script looks for to their web URLs
images_to_download = {
    # 1. Your original base card tract image
    "base_card.jpeg": "https://pub-c06316203b53460e90b84cb1f00cb0ec.r2.dev/tract_base.jpeg",
    
    # 2. The four design element PNGs with transparent backgrounds
    "praying_hands.png": "http://googleusercontent.com/image_collection/image_retrieval/7299306657974641378_0",
    "vine_border.png": "http://googleusercontent.com/image_collection/image_retrieval/15749048092706089976_0",
    "cross_glow.png": "http://googleusercontent.com/image_collection/image_retrieval/16216846121536657153_0",
    "dove.png": "http://googleusercontent.com/image_collection/image_retrieval/17490197199950563231_0"
}

print("Downloading files directly into your active Jupyter workspace...")

for filename, url in images_to_download.items():
    try:
        # Using a browser agent header to prevent download blocks
        request_wrapper = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        with urllib.request.urlopen(request_wrapper) as response, open(filename, 'wb') as local_file:
            local_file.write(response.read())
        print(f" Saved successfully: {filename}")
    except Exception as error:
        print(f" Could not download {filename}. Error details: {error}")

print("\nFinished! All files are now in your workspace directory.")
# Out:
# Downloading files directly into your active Jupyter workspace...
#  Could not download base_card.jpeg. Error details: HTTP Error 401: Unauthorized
#  Could not download praying_hands.png. Error details: HTTP Error 404: Not Found
#  Could not download vine_border.png. Error details: HTTP Error 404: Not Found
#  Could not download cross_glow.png. Error details: HTTP Error 404: Not Found
#  Could not download dove.png. Error details: HTTP Error 404: Not Found
#
# Finished! All files are now in your workspace directory.

# %%
from PIL import Image

def generate_tract_design():
    # 1. Open the original base card image
    base_image = Image.open("base_card.jpeg").convert("RGBA")
    card_width, card_height = base_image.size

    # Helper function to open and resize transparent design elements
    def load_element(filename, target_width):
        img = Image.open(filename).convert("RGBA")
        # Calculate height keeping the aspect ratio perfect
        aspect_ratio = img.height / img.width
        target_height = int(target_width * aspect_ratio)
        return img.resize((target_width, target_height), Image.Resampling.LANCZOS)

    # 2. Load and resize each design asset
    # Adjust the target widths (pixels) to change asset sizes on the card
    hands = load_element("praying_hands.png", target_width=320)
    vine = load_element("vine_border.png", target_width=220)
    cross = load_element("cross_glow.png", target_width=180)
    dove = load_element("dove.png", target_width=140)

    # 3. Paste elements using coordinates matching your 2, 3, 4, 5 positions
    # Format: (X-coordinate, Y-coordinate). Top-left of the card is (0,0)

    # Position 2: Watermark style behind the Sinner's prayer box center
    # Adjust opacity of the hands to 35% so the text remains completely legible
    hands_alpha = hands.split()[3]
    hands_alpha = hands_alpha.point(lambda p: int(p * 0.35))
    hands.putalpha(hands_alpha)
    # Center the hands horizontally over the box area
    hands_x = (card_width - hands.width) // 2
    base_image.paste(hands, (hands_x, 340), mask=hands)

    # Position 3: Lower-left decorative border accent
    base_image.paste(vine, (20, card_height - vine.height - 40), mask=vine)

    # Position 4: Lower-right illuminated cross
    base_image.paste(cross, (card_width - cross.width - 40, card_height - cross.height - 40), mask=cross)

    # Position 5: Center bottom dove accent right next to the text
    # Placed right beside the "God bless you." text at the bottom center
    dove_x = (card_width // 2) + 60 
    base_image.paste(dove, (dove_x, card_height - dove.height - 35), mask=dove)

    # 4. Convert back to RGB format and save the final print-ready image
    final_design = base_image.convert("RGB")
    final_design.save("final_prayer_tract.jpg", "JPEG", quality=95)
    print("Design updated successfully! Checked final_prayer_tract.jpg")

if __name__ == "__main__":
    generate_tract_design()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 52
#      49     print("Design updated successfully! Checked final_prayer_tract.jpg")
#      51 if __name__ == "__main__":
# ---> 52     generate_tract_design()
#
# Cell In[3], line 5, in generate_tract_design()
#       3 def generate_tract_design():
#       4     # 1. Open the original base card image
# ----> 5     base_image = Image.open("base_card.jpeg").convert("RGBA")
#       6     card_width, card_height = base_image.size
#       8     # Helper function to open and resize transparent design elements
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'base_card.jpeg'
